# %% [markdown]
# ## CV20 - 스티커를 붙여주자
# ### Step 1. 스티커 구하기 혹은 만들기
# 왕관을 붙여주기

# %%
import os
work_dir = os.getenv('HOME') + '/aiffel/face_detector/'

os.chdir(work_dir)

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import cv2
img_sticker = cv2.imread('./king.png')

# %% [markdown]
# ### Step 2. SSD 모델을 통해 얼굴 bounding box 찾기

# %% [markdown]
# #### tf_example 생성

# %%
def get_box(data):
    x0 = int(data[0])
    y0 = int(data[1])
    w = int(data[2])
    h = int(data[3])
    return x0, y0, w, h

# %%
def parse_widerface(config_path):
    boxes_per_img = []
    with open(config_path) as fp:
        line = fp.readline()
        cnt = 1
        while line:
            num_of_obj = int(fp.readline())
            boxes = []
            for i in range(num_of_obj):
                obj_box = fp.readline().split(' ')
                x0, y0, w, h = get_box(obj_box)
                if w == 0:
                    # remove boxes with no width
                    continue
                if h == 0:
                    # remove boxes with no height
                    continue
                # Because our network is outputting 7x7 grid then it's not worth processing images with more than
                # 5 faces because it's highly probable they are close to each other.
                # You could remove this filter if you decide to switch to larger grid (like 14x14)
                # Don't worry about number of train data because even with this filter we have around 16k samples
                boxes.append([x0, y0, w, h])
            if num_of_obj == 0:
                obj_box = fp.readline().split(' ')
                x0, y0, w, h = get_box(obj_box)
                boxes.append([x0, y0, w, h])
            boxes_per_img.append((line.strip(), boxes))
            line = fp.readline()
            cnt += 1

    return boxes_per_img

# %%
def process_image(image_file):
    image_string = tf.io.read_file(image_file)
    try:
        image_data = tf.image.decode_jpeg(image_string, channels=3)
        return 0, image_string, image_data
    except tf.errors.InvalidArgumentError:
        logging.info('{}: Invalid JPEG data or crop window'.format(image_file))
        return 1, image_string, None

# %%
def xywh_to_voc(file_name, boxes, image_data):
    shape = image_data.shape
    image_info = {}
    image_info['filename'] = file_name
    image_info['width'] = shape[1]
    image_info['height'] = shape[0]
    image_info['depth'] = 3

    difficult = []
    classes = []
    xmin, ymin, xmax, ymax = [], [], [], []

    for box in boxes:
        classes.append(1)
        difficult.append(0)
        xmin.append(box[0])
        ymin.append(box[1])
        xmax.append(box[0] + box[2])
        ymax.append(box[1] + box[3])
    image_info['class'] = classes
    image_info['xmin'] = xmin
    image_info['ymin'] = ymin
    image_info['xmax'] = xmax
    image_info['ymax'] = ymax
    image_info['difficult'] = difficult

    return image_info

# %%
def make_example(image_string, image_info_list):

    for info in image_info_list:
        filename = info['filename']
        width = info['width']
        height = info['height']
        depth = info['depth']
        classes = info['class']
        xmin = info['xmin']
        ymin = info['ymin']
        xmax = info['xmax']
        ymax = info['ymax']

    if isinstance(image_string, type(tf.constant(0))):
        encoded_image = [image_string.numpy()]
    else:
        encoded_image = [image_string]

    base_name = [tf.compat.as_bytes(os.path.basename(filename))]

    example = tf.train.Example(features=tf.train.Features(feature={
        'filename':tf.train.Feature(bytes_list=tf.train.BytesList(value=base_name)),
        'height':tf.train.Feature(int64_list=tf.train.Int64List(value=[height])),
        'width':tf.train.Feature(int64_list=tf.train.Int64List(value=[width])),
        'classes':tf.train.Feature(int64_list=tf.train.Int64List(value=classes)),
        'x_mins':tf.train.Feature(float_list=tf.train.FloatList(value=xmin)),
        'y_mins':tf.train.Feature(float_list=tf.train.FloatList(value=ymin)),
        'x_maxes':tf.train.Feature(float_list=tf.train.FloatList(value=xmax)),
        'y_maxes':tf.train.Feature(float_list=tf.train.FloatList(value=ymax)),
        'image_raw':tf.train.Feature(bytes_list=tf.train.BytesList(value=encoded_image))
    }))
    return example

# %%
import logging
import tqdm

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
rootPath = os.getenv('HOME')+'/aiffel/face_detector'
dataset_path = 'widerface'

if not os.path.isdir(dataset_path):
    logging.info('Please define valid dataset path.')
else:
    logging.info('Loading {}'.format(dataset_path))

logging.info('Reading configuration...')

for split in ['train', 'val']:
    output_file = rootPath + '/dataset/train_mask.tfrecord' if split == 'train' else rootPath + '/dataset/val_mask.tfrecord'

    with tf.io.TFRecordWriter(output_file) as writer:

        counter = 0
        skipped = 0
        anno_txt = 'wider_face_train_bbx_gt.txt' if split == 'train' else 'wider_face_val_bbx_gt.txt'
        file_path = 'WIDER_train' if split == 'train' else 'WIDER_val'
        for info in tqdm.tqdm(parse_widerface(os.path.join(rootPath, dataset_path, 'wider_face_split', anno_txt))):
            image_file = os.path.join(rootPath, dataset_path, file_path, 'images', info[0])

            error, image_string, image_data = process_image(image_file)
            boxes = xywh_to_voc(image_file, info[1], image_data)

            if not error:
                tf_example = make_example(image_string, [boxes])

                writer.write(tf_example.SerializeToString())
                counter += 1

            else:
                skipped += 1
                logging.info('Skipped {:d} of {:d} images.'.format(skipped, counter))

    logging.info('Wrote {} images to {}'.format(counter, output_file))
# Out:
# 100%|██████████| 12880/12880 [01:00<00:00, 214.16it/s]
# 100%|██████████| 3226/3226 [00:17<00:00, 189.17it/s]

# %% [markdown]
# #### Augmentation 적용

# %%
def _crop(img, labels, max_loop=250):
    shape = tf.shape(img)

    def matrix_iof(a, b):
        """
        return iof of a and b, numpy version for data augenmentation
        """
        lt = tf.math.maximum(a[:, tf.newaxis, :2], b[:, :2])
        rb = tf.math.minimum(a[:, tf.newaxis, 2:], b[:, 2:])

        area_i = tf.math.reduce_prod(rb - lt, axis=2) * \
            tf.cast(tf.reduce_all(lt < rb, axis=2), tf.float32)
        area_a = tf.math.reduce_prod(a[:, 2:] - a[:, :2], axis=1)
        return area_i / tf.math.maximum(area_a[:, tf.newaxis], 1)

    def crop_loop_body(i, img, labels):
        valid_crop = tf.constant(1, tf.int32)

        pre_scale = tf.constant([0.3, 0.45, 0.6, 0.8, 1.0], dtype=tf.float32)
        scale = pre_scale[tf.random.uniform([], 0, 5, dtype=tf.int32)]
        short_side = tf.cast(tf.minimum(shape[0], shape[1]), tf.float32)
        h = w = tf.cast(scale * short_side, tf.int32)
        h_offset = tf.random.uniform([], 0, shape[0] - h + 1, dtype=tf.int32)
        w_offset = tf.random.uniform([], 0, shape[1] - w + 1, dtype=tf.int32)
        roi = tf.stack([w_offset, h_offset, w_offset + w, h_offset + h])
        roi = tf.cast(roi, tf.float32)


        value = matrix_iof(labels[:, :4], roi[tf.newaxis])
        valid_crop = tf.cond(tf.math.reduce_any(value >= 1),
                             lambda: valid_crop, lambda: 0)

        centers = (labels[:, :2] + labels[:, 2:4]) / 2
        mask_a = tf.reduce_all(
            tf.math.logical_and(roi[:2] < centers, centers < roi[2:]),
            axis=1)
        labels_t = tf.boolean_mask(labels, mask_a)
        valid_crop = tf.cond(tf.reduce_any(mask_a),
                             lambda: valid_crop, lambda: 0)

        img_t = img[h_offset:h_offset + h, w_offset:w_offset + w, :]
        h_offset = tf.cast(h_offset, tf.float32)
        w_offset = tf.cast(w_offset, tf.float32)
        labels_t = tf.stack(
            [labels_t[:, 0] - w_offset,  labels_t[:, 1] - h_offset,
             labels_t[:, 2] - w_offset,  labels_t[:, 3] - h_offset,
             labels_t[:, 4]], axis=1)

        return tf.cond(valid_crop == 1,
                       lambda: (max_loop, img_t, labels_t),
                       lambda: (i + 1, img, labels))

    _, img, labels = tf.while_loop(
        lambda i, img, labels: tf.less(i, max_loop),
        crop_loop_body,
        [tf.constant(-1), img, labels],
        shape_invariants=[tf.TensorShape([]),
                          tf.TensorShape([None, None, 3]),
                          tf.TensorShape([None, 5])])

    return img, labels

# %%
def _pad_to_square(img):
    height = tf.shape(img)[0]
    width = tf.shape(img)[1]

    def pad_h():
        img_pad_h = tf.ones([width - height, width, 3]) * tf.reduce_mean(img, axis=[0, 1], keepdims=True)
        return tf.concat([img, img_pad_h], axis=0)

    def pad_w():
        img_pad_w = tf.ones([height, height - width, 3]) * tf.reduce_mean(img, axis=[0, 1], keepdims=True)
        return tf.concat([img, img_pad_w], axis=1)

    img = tf.case([(tf.greater(height, width), pad_w),
                   (tf.less(height, width), pad_h)], default=lambda: img)

    return img

# %%
def _resize(img, labels, img_dim):
    ''' # resize and boxes coordinate to percent'''
    w_f = tf.cast(tf.shape(img)[1], tf.float32)
    h_f = tf.cast(tf.shape(img)[0], tf.float32)
    locs = tf.stack([labels[:, 0] / w_f,  labels[:, 1] / h_f,
                     labels[:, 2] / w_f,  labels[:, 3] / h_f] ,axis=1)
    locs = tf.clip_by_value(locs, 0, 1.0)
    labels = tf.concat([locs, labels[:, 4][:, tf.newaxis]], axis=1)

    resize_case = tf.random.uniform([], 0, 5, dtype=tf.int32)
    if isinstance(img_dim, int):
        img_dim = (img_dim, img_dim)
    elif isinstance(img_dim,tuple):
        img_dim = img_dim
    else:
        raise Exception('Type error of input image size format,tuple or int. ')

    def resize(method):
        def _resize():
            #　size h,w
            return tf.image.resize(img, [img_dim[0], img_dim[1]], method=method, antialias=True)
        return _resize

    img = tf.case([(tf.equal(resize_case, 0), resize('bicubic')),
                   (tf.equal(resize_case, 1), resize('area')),
                   (tf.equal(resize_case, 2), resize('nearest')),
                   (tf.equal(resize_case, 3), resize('lanczos3'))],
                  default=resize('bilinear'))

    return img, labels

# %%
def _flip(img, labels):
    flip_case = tf.random.uniform([], 0, 2, dtype=tf.int32)

    def flip_func():
        flip_img = tf.image.flip_left_right(img)
        flip_labels = tf.stack([1 - labels[:, 2],  labels[:, 1],
                                1 - labels[:, 0],  labels[:, 3],
                                labels[:, 4]], axis=1)

        return flip_img, flip_labels

    img, labels = tf.case([(tf.equal(flip_case, 0), flip_func)],default=lambda: (img, labels))

    return img, labels

# %%
def _distort(img):
    img = tf.image.random_brightness(img, 0.4)
    img = tf.image.random_contrast(img, 0.5, 1.5)
    img = tf.image.random_saturation(img, 0.5, 1.5)
    img = tf.image.random_hue(img, 0.1)

    return img

# %%
def _intersect(box_a, box_b):
    """ We resize both tensors to [A,B,2]:
    [A,2] -> [A,1,2] -> [A,B,2]
    [B,2] -> [1,B,2] -> [A,B,2]
    Then we compute the area of intersect between box_a and box_b.
    Args:
      box_a: (tensor) bounding boxes, Shape: [A,4].
      box_b: (tensor) bounding boxes, Shape: [B,4].
    Return:
      (tensor) intersection area, Shape: [A,B].
    """
    A = tf.shape(box_a)[0]
    B = tf.shape(box_b)[0]
    max_xy = tf.minimum(
        tf.broadcast_to(tf.expand_dims(box_a[:, 2:], 1), [A, B, 2]),
        tf.broadcast_to(tf.expand_dims(box_b[:, 2:], 0), [A, B, 2]))
    min_xy = tf.maximum(
        tf.broadcast_to(tf.expand_dims(box_a[:, :2], 1), [A, B, 2]),
        tf.broadcast_to(tf.expand_dims(box_b[:, :2], 0), [A, B, 2]))
    inter = tf.clip_by_value(max_xy - min_xy, 0.0, 512.0)
    return inter[:, :, 0] * inter[:, :, 1]

# %%
def _jaccard(box_a, box_b):
    """Compute the jaccard overlap of two sets of boxes.  The jaccard overlap
    is simply the intersection over union of two boxes.  Here we operate on
    ground truth boxes and default boxes.
    E.g.:
        A ∩ B / A ∪ B = A ∩ B / (area(A) + area(B) - A ∩ B)
    Args:
        box_a: (tensor) Ground truth bounding boxes, Shape: [num_objects,4]
        box_b: (tensor) Prior boxes from priorbox layers, Shape: [num_priors,4]
    Return:
        jaccard overlap: (tensor) Shape: [box_a.size(0), box_b.size(0)]
    """
    inter = _intersect(box_a, box_b)
    area_a = tf.broadcast_to(
        tf.expand_dims(
            (box_a[:, 2] - box_a[:, 0]) * (box_a[:, 3] - box_a[:, 1]), 1),
        tf.shape(inter))  # [A,B]
    area_b = tf.broadcast_to(
        tf.expand_dims(
            (box_b[:, 2] - box_b[:, 0]) * (box_b[:, 3] - box_b[:, 1]), 0),
        tf.shape(inter))  # [A,B]
    union = area_a + area_b - inter
    return inter / union  # [A,B]

# %%
def _encode_bbox(matched, priors, variances):
    """Encode the variances from the priorbox layers into the ground truth
    boxes we have matched (based on jaccard overlap) with the prior boxes.
    Args:
        matched: (tensor) Coords of ground truth for each prior in point-form
            Shape: [num_priors, 4].
        priors: (tensor) Prior boxes in center-offset form
            Shape: [num_priors,4].
        variances: (list[float]) Variances of prior boxes
    Return:
        encoded boxes (tensor), Shape: [num_priors, 4]
    """
    # dist b/t match center and prior's center
    g_cxcy = (matched[:, :2] + matched[:, 2:]) / 2 - priors[:, :2]

    # encode variance
    g_cxcy /= (variances[0] * priors[:, 2:])

    # match wh / prior wh
    g_wh = (matched[:, 2:] - matched[:, :2]) / priors[:, 2:]
    g_wh = tf.math.log(g_wh) / variances[1]

    # return target for smooth_l1_loss
    return tf.concat([g_cxcy, g_wh], 1)  # [num_priors,4]

# %%
# tfrecord 데이터셋의 라벨을 가공한다
def encode_tf(labels, priors, match_thresh, variances=None):
    """tensorflow encoding"""
    if variances is None:
        variances = [0.1, 0.2]

    priors = tf.cast(priors, tf.float32)
    bbox = labels[:, :4]
    conf = labels[:, -1]

    # jaccard index
    overlaps = _jaccard(bbox, priors)
    best_prior_overlap = tf.reduce_max(overlaps, 1)
    best_prior_idx = tf.argmax(overlaps, 1, tf.int32)

    best_truth_overlap = tf.reduce_max(overlaps, 0)
    best_truth_idx = tf.argmax(overlaps, 0, tf.int32)

    best_truth_overlap = tf.tensor_scatter_nd_update(
        best_truth_overlap, tf.expand_dims(best_prior_idx, 1),
        tf.ones_like(best_prior_idx, tf.float32) * 2.)
    best_truth_idx = tf.tensor_scatter_nd_update(
        best_truth_idx, tf.expand_dims(best_prior_idx, 1),
        tf.range(tf.size(best_prior_idx), dtype=tf.int32))

    # Scale Ground-Truth Boxes
    matches_bbox = tf.gather(bbox, best_truth_idx)  # [num_priors, 4]
    loc_t = _encode_bbox(matches_bbox, priors, variances)
    conf_t = tf.gather(conf, best_truth_idx)  # [num_priors]
    conf_t = tf.where(tf.less(best_truth_overlap, match_thresh), tf.zeros_like(conf_t), conf_t)

    return tf.concat([loc_t, conf_t[..., tf.newaxis]], axis=1)

# %%
def _transform_data(img_dim, using_crop,using_flip, using_distort, using_encoding,using_normalizing, priors,
                    match_thresh,  variances):
    def transform_data(img, labels):
        img = tf.cast(img, tf.float32)
        if using_crop:
        # randomly crop
            img, labels = _crop(img, labels)

            # padding to square
            img = _pad_to_square(img)

        # resize and boxes coordinate to percent
        img, labels = _resize(img, labels, img_dim)

        # randomly left-right flip
        if using_flip:
            img, labels = _flip(img, labels)

        # distort
        if using_distort:
            img = _distort(img)

        # encode labels to feature targets
        if using_encoding:
            labels = encode_tf(labels=labels, priors=priors, match_thresh=match_thresh, variances=variances)
        if using_normalizing:
            img=(img/255.0-0.5)/1.0

        return img, labels
    return transform_data

# %%
def _parse_tfrecord(img_dim,using_crop, using_flip, using_distort,
                    using_encoding, using_normalizing,priors, match_thresh,  variances):
    def parse_tfrecord(tfrecord):
        features = {
            'filename': tf.io.FixedLenFeature([], tf.string),
            'height': tf.io.FixedLenFeature([], tf.int64),
            'width': tf.io.FixedLenFeature([], tf.int64),
            'classes': tf.io.VarLenFeature(tf.int64),
            'x_mins': tf.io.VarLenFeature(tf.float32),
            'y_mins': tf.io.VarLenFeature(tf.float32),
            'x_maxes': tf.io.VarLenFeature(tf.float32),
            'y_maxes': tf.io.VarLenFeature(tf.float32),
            'difficult':tf.io.VarLenFeature(tf.int64),
            'image_raw': tf.io.FixedLenFeature([], tf.string),
           }

        parsed_example = tf.io.parse_single_example(tfrecord, features)
        img = tf.image.decode_jpeg(parsed_example['image_raw'], channels=3)

        width = tf.cast(parsed_example['width'], tf.float32)
        height = tf.cast(parsed_example['height'], tf.float32)

        labels = tf.sparse.to_dense(parsed_example['classes'])
        labels = tf.cast(labels, tf.float32)

        labels = tf.stack(
            [tf.sparse.to_dense(parsed_example['x_mins']),
             tf.sparse.to_dense(parsed_example['y_mins']),
             tf.sparse.to_dense(parsed_example['x_maxes']),
             tf.sparse.to_dense(parsed_example['y_maxes']),labels], axis=1)

        img, labels = _transform_data(
            img_dim, using_crop,using_flip, using_distort, using_encoding, using_normalizing,priors,
            match_thresh,  variances)(img, labels)

        return img, labels
    return parse_tfrecord

# %%
def load_tfrecord_dataset(tfrecord_name, batch_size, img_dim,
                          using_crop=True,using_flip=True, using_distort=True,
                          using_encoding=True, using_normalizing=True,
                          priors=None, match_thresh=0.45,variances=None,
                          shuffle=True, repeat=True,buffer_size=10240):

    if variances is None:
        variances = [0.1, 0.2]

    """load dataset from tfrecord"""
    if not using_encoding:
        assert batch_size == 1
    else:
        assert priors is not None

    raw_dataset = tf.data.TFRecordDataset(tfrecord_name)
    raw_dataset = raw_dataset.cache()
    if repeat:
        raw_dataset = raw_dataset.repeat()
    if shuffle:
        raw_dataset = raw_dataset.shuffle(buffer_size=buffer_size)


    dataset = raw_dataset.map(
        _parse_tfrecord(img_dim, using_crop, using_flip, using_distort,
                        using_encoding, using_normalizing,priors, match_thresh,  variances),
        num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(
        buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
def load_dataset(cfg, priors, shuffle=True, buffer_size=10240,train=True):
    """load dataset"""
    global dataset
    if train:
        logging.info("load train dataset from {}".format(cfg['dataset_path']))
        dataset = load_tfrecord_dataset(
            tfrecord_name=os.path.join(rootPath, cfg['dataset_path']),
            batch_size=cfg['batch_size'],
            img_dim=cfg['input_size'],
            using_crop=cfg['using_crop'],
            using_flip=cfg['using_flip'],
            using_distort=cfg['using_distort'],
            using_encoding=True,
            using_normalizing=cfg['using_normalizing'],
            priors=priors,
            match_thresh=cfg['match_thresh'],
            variances=cfg['variances'],
            shuffle=shuffle,
            repeat=True,
            buffer_size=buffer_size)
    else:
        dataset = load_tfrecord_dataset(
            tfrecord_name=os.path.join(rootPath, cfg['val_path']),
            batch_size=cfg['batch_size'],
            img_dim=cfg['input_size'],
            using_crop=False,
            using_flip=False,
            using_distort=False,
            using_encoding=True,
            using_normalizing=True,
            priors=priors,
            match_thresh=cfg['match_thresh'],
            variances=cfg['variances'],
            shuffle=shuffle,
            repeat=False,
            buffer_size=buffer_size)
        logging.info("load validation dataset from {}".format(cfg['val_path']))

    return dataset

# %% [markdown]
# #### Prior box

# %%
cfg = {
    # general setting
    "batch_size": 64,
    "input_size": (240, 320),  # (h,w)

    # training dataset
    "dataset_path": 'dataset/train_mask.tfrecord',  # 'dataset/trainval_mask.tfrecord'
    "val_path": 'dataset/val_mask.tfrecord',  #
    "dataset_len": 12880,  # train 6115 , trainval 7954, number of training samples
    "val_len": 3226,
    "using_crop": True,
    "using_bin": True,
    "using_flip": True,
    "using_distort": True,
    "using_normalizing": True,
    "labels_list": ['background', 'face'],  # xml annotation

    # anchor setting
    "min_sizes":[[10, 16, 24], [32, 48], [64, 96], [128, 192, 256]],
    "steps": [8, 16, 32, 64],
    "match_thresh": 0.45,
    "variances": [0.1, 0.2],
    "clip": False,

    # network
    "base_channel": 16,

    # training setting
    "resume": False,  # if False,training from scratch
    "epoch": 200,
    "init_lr": 1e-2,
    "lr_decay_epoch": [50, 70],
    "lr_rate": 0.1,
    "warmup_epoch": 5,
    "min_lr": 1e-4,

    "weights_decay": 5e-4,
    "momentum": 0.9,
    "save_freq": 10, #frequency of save model weights

    # inference
    "score_threshold": 0.5,
    "nms_threshold": 0.4,
    "max_number_keep": 200
}

# %%
import math
from itertools import product

def prior_box(cfg,image_sizes=None):
    """prior box"""
    if image_sizes is None:
        image_sizes = cfg['input_size']
    min_sizes=cfg["min_sizes"]
    steps=cfg["steps"]
    clip=cfg["clip"]

    if isinstance(image_sizes, int):
        image_sizes = (image_sizes, image_sizes)
    elif isinstance(image_sizes, tuple):
        image_sizes = image_sizes
    else:
        raise Exception('Type error of input image size format,tuple or int. ')

    for m in range(4):
        if (steps[m] != pow(2, (m + 3))):
            print("steps must be [8,16,32,64]")
            sys.exit()

    assert len(min_sizes) == len(steps), "anchors number didn't match the feature map layer."

    feature_maps = [
        [math.ceil(image_sizes[0] / step), math.ceil(image_sizes[1] / step)]
        for step in steps]

    anchors = []
    num_box_fm_cell=[]
    for k, f in enumerate(feature_maps):
        num_box_fm_cell.append(len(min_sizes[k]))
        for i, j in product(range(f[0]), range(f[1])):
            for min_size in min_sizes[k]:
                if isinstance(min_size, int):
                    min_size = (min_size, min_size)
                elif isinstance(min_size, tuple):
                    min_size=min_size
                else:
                    raise Exception('Type error of min_sizes elements format,tuple or int. ')
                s_kx = min_size[1] / image_sizes[1]
                s_ky = min_size[0] / image_sizes[0]
                cx = (j + 0.5) * steps[k] / image_sizes[1]
                cy = (i + 0.5) * steps[k] / image_sizes[0]
                anchors += [cx, cy, s_kx, s_ky]

    output = np.asarray(anchors).reshape([-1, 4])

    if clip:
        output = np.clip(output, 0, 1)
    return output,num_box_fm_cell

# %% [markdown]
# #### SSD 모델 생성

# %%
import tensorflow as tf

def _conv_block(inputs, filters, kernel=(3, 3), strides=(1, 1), use_bn=True, padding=None, block_id=None):
    """Adds an initial convolution layer (with batch normalization and relu).
    # Returns
        Output tensor of block.
    """
    if block_id is None:
        block_id = (tf.keras.backend.get_uid())

    if strides == (2, 2):
        x = tf.keras.layers.ZeroPadding2D(padding=((1, 1), (1, 1)), name='conv_pad_%d' % block_id)(inputs)
        x = tf.keras.layers.Conv2D(filters, kernel,
                                   padding='valid',
                                   use_bias=False if use_bn else True,
                                   strides=strides,
                                   name='conv_%d' % block_id)(x)
    else:
        x = tf.keras.layers.Conv2D(filters, kernel,
                                   padding='same',
                                   use_bias=False if use_bn else True,
                                   strides=strides,
                                   name='conv_%d' % block_id)(inputs)
    if use_bn:
        x = tf.keras.layers.BatchNormalization(name='conv_bn_%d' % block_id)(x)
    return tf.keras.layers.ReLU(name='conv_relu_%d' % block_id)(x)

# %%
def _depthwise_conv_block(inputs, pointwise_conv_filters,
                          depth_multiplier=1, strides=(1, 1), use_bn=True, block_id=None):
    """Adds a depthwise convolution block.
        # Returns
        Output tensor of block.
    """
    if block_id is None:
        block_id = (tf.keras.backend.get_uid())

    if strides == (1, 1):
        x = inputs
    else:
        x = tf.keras.layers.ZeroPadding2D(((1, 1), (1, 1)), name='conv_pad_%d' % block_id)(inputs)

    x = tf.keras.layers.DepthwiseConv2D((3, 3),
                                        padding='same' if strides == (1, 1) else 'valid',
                                        depth_multiplier=depth_multiplier,
                                        strides=strides,
                                        use_bias=False if use_bn else True,
                                        name='conv_dw_%d' % block_id)(x)
    if use_bn:
        x = tf.keras.layers.BatchNormalization(name='conv_dw_%d_bn' % block_id)(x)
    x = tf.keras.layers.ReLU(name='conv_dw_%d_relu' % block_id)(x)

    x = tf.keras.layers.Conv2D(pointwise_conv_filters, (1, 1),
                               padding='same',
                               use_bias=False if use_bn else True,
                               strides=(1, 1),
                               name='conv_pw_%d' % block_id)(x)
    if use_bn:
        x = tf.keras.layers.BatchNormalization(name='conv_pw_%d_bn' % block_id)(x)
    return tf.keras.layers.ReLU(name='conv_pw_%d_relu' % block_id)(x)

# %%
def _branch_block(input, filters):

    x = tf.keras.layers.Conv2D(filters, kernel_size=(3, 3), padding='same')(input)
    x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Conv2D(filters, kernel_size=(3, 3), padding='same')(x)

    x1 = tf.keras.layers.Conv2D(filters * 2, kernel_size=(3, 3), padding='same')(input)

    x = tf.keras.layers.Concatenate(axis=-1)([x, x1])

    return tf.keras.layers.ReLU()(x)

# %%
def _create_head_block(inputs, filters, strides=(1, 1), block_id=None):
    x = tf.keras.layers.Conv2D(filters, kernel_size=(3, 3), strides=strides, padding='same')(inputs)
    return x

# %%
def _compute_heads(x, idx, num_class, num_cell):
    """ Compute outputs of classification and regression heads
    Args:
        x: the input feature map
        idx: index of the head layer
    Returns:
        conf: output of the idx-th classification head
        loc: output of the idx-th regression head
    """
    conf = _create_head_block(inputs=x, filters=num_cell[idx] * num_class)
    conf = tf.keras.layers.Reshape((-1, num_class))(conf)
    loc = _create_head_block(inputs=x, filters=num_cell[idx] * 4)
    loc = tf.keras.layers.Reshape((-1, 4))(loc)

    return conf, loc

# %%
def SsdModel(cfg, num_cell, training=False, name='ssd_model'):
    image_sizes = cfg['input_size']   if training else None
    if isinstance(image_sizes, int):
        image_sizes = (image_sizes, image_sizes)
    elif isinstance(image_sizes, tuple):
        image_sizes = image_sizes
    elif image_sizes == None:
        image_sizes = (None, None)
    else:
        raise Exception('Type error of input image size format,tuple or int. ')

    base_channel = cfg["base_channel"]
    num_class = len(cfg['labels_list'])

    x = inputs = tf.keras.layers.Input(shape=[image_sizes[0], image_sizes[1], 3], name='input_image')

    x = _conv_block(x, base_channel, strides=(2, 2))  # 120*160*16
    x = _conv_block(x, base_channel * 2, strides=(1, 1))
    x = _conv_block(x, base_channel * 2, strides=(2, 2))  # 60*80
    x = _conv_block(x, base_channel * 2, strides=(1, 1))
    x = _conv_block(x, base_channel * 4, strides=(2, 2))  # 30*40
    x = _conv_block(x, base_channel * 4, strides=(1, 1))
    x = _conv_block(x, base_channel * 4, strides=(1, 1))
    x = _conv_block(x, base_channel * 4, strides=(1, 1))
    x1 = _branch_block(x, base_channel)

    x = _conv_block(x, base_channel * 8, strides=(2, 2))  # 15*20
    x = _conv_block(x, base_channel * 8, strides=(1, 1))
    x = _conv_block(x, base_channel * 8, strides=(1, 1))
    x2 = _branch_block(x, base_channel)

    x = _depthwise_conv_block(x, base_channel * 16, strides=(2, 2))  # 8*10
    x = _depthwise_conv_block(x, base_channel * 16, strides=(1, 1))
    x3 = _branch_block(x, base_channel)

    x = _depthwise_conv_block(x, base_channel * 16, strides=(2, 2))  # 4*5
    x4 = _branch_block(x, base_channel)

    extra_layers = [x1, x2, x3, x4]

    confs = []
    locs = []

    head_idx = 0
    assert len(extra_layers) == len(num_cell)
    for layer in extra_layers:
        conf, loc = _compute_heads(layer, head_idx, num_class, num_cell)
        confs.append(conf)
        locs.append(loc)

        head_idx += 1

    confs = tf.keras.layers.Concatenate(axis=1, name="face_classes")(confs)
    locs = tf.keras.layers.Concatenate(axis=1, name="face_boxes")(locs)

    predictions = tf.keras.layers.Concatenate(axis=2, name='predictions')([locs, confs])


    model = tf.keras.Model(inputs=inputs, outputs=predictions, name=name)
    return model

# %%
model = SsdModel(cfg, num_cell=[3, 2, 2, 3], training=False)
model.summary()
# Out:
# Model: "ssd_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, None, None,  0
# __________________________________________________________________________________________________
# conv_pad_1 (ZeroPadding2D)      (None, None, None, 3 0           input_image[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, None, None, 1 432         conv_pad_1[0][0]
# __________________________________________________________________________________________________
# conv_bn_1 (BatchNormalization)  (None, None, None, 1 64          conv_1[0][0]
# __________________________________________________________________________________________________
# conv_relu_1 (ReLU)              (None, None, None, 1 0           conv_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, None, None, 3 4608        conv_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_bn_2 (BatchNormalization)  (None, None, None, 3 128         conv_2[0][0]
# __________________________________________________________________________________________________
# conv_relu_2 (ReLU)              (None, None, None, 3 0           conv_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_3 (ZeroPadding2D)      (None, None, None, 3 0           conv_relu_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, None, None, 3 9216        conv_pad_3[0][0]
# __________________________________________________________________________________________________
# conv_bn_3 (BatchNormalization)  (None, None, None, 3 128         conv_3[0][0]
# __________________________________________________________________________________________________
# conv_relu_3 (ReLU)              (None, None, None, 3 0           conv_bn_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, None, None, 3 9216        conv_relu_3[0][0]
# __________________________________________________________________________________________________
# conv_bn_4 (BatchNormalization)  (None, None, None, 3 128         conv_4[0][0]
# __________________________________________________________________________________________________
# conv_relu_4 (ReLU)              (None, None, None, 3 0           conv_bn_4[0][0]
# __________________________________________________________________________________________________
# conv_pad_5 (ZeroPadding2D)      (None, None, None, 3 0           conv_relu_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, None, None, 6 18432       conv_pad_5[0][0]
# __________________________________________________________________________________________________
# conv_bn_5 (BatchNormalization)  (None, None, None, 6 256         conv_5[0][0]
# __________________________________________________________________________________________________
# conv_relu_5 (ReLU)              (None, None, None, 6 0           conv_bn_5[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, None, None, 6 36864       conv_relu_5[0][0]
# __________________________________________________________________________________________________
# conv_bn_6 (BatchNormalization)  (None, None, None, 6 256         conv_6[0][0]
# __________________________________________________________________________________________________
# conv_relu_6 (ReLU)              (None, None, None, 6 0           conv_bn_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, None, None, 6 36864       conv_relu_6[0][0]
# __________________________________________________________________________________________________
# conv_bn_7 (BatchNormalization)  (None, None, None, 6 256         conv_7[0][0]
# __________________________________________________________________________________________________
# conv_relu_7 (ReLU)              (None, None, None, 6 0           conv_bn_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, None, None, 6 36864       conv_relu_7[0][0]
# __________________________________________________________________________________________________
# conv_bn_8 (BatchNormalization)  (None, None, None, 6 256         conv_8[0][0]
# __________________________________________________________________________________________________
# conv_relu_8 (ReLU)              (None, None, None, 6 0           conv_bn_8[0][0]
# __________________________________________________________________________________________________
# conv_pad_9 (ZeroPadding2D)      (None, None, None, 6 0           conv_relu_8[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, None, None, 1 73728       conv_pad_9[0][0]
# __________________________________________________________________________________________________
# conv_bn_9 (BatchNormalization)  (None, None, None, 1 512         conv_9[0][0]
# __________________________________________________________________________________________________
# conv_relu_9 (ReLU)              (None, None, None, 1 0           conv_bn_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, None, None, 1 147456      conv_relu_9[0][0]
# __________________________________________________________________________________________________
# conv_bn_10 (BatchNormalization) (None, None, None, 1 512         conv_10[0][0]
# __________________________________________________________________________________________________
# conv_relu_10 (ReLU)             (None, None, None, 1 0           conv_bn_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, None, None, 1 147456      conv_relu_10[0][0]
# __________________________________________________________________________________________________
# conv_bn_11 (BatchNormalization) (None, None, None, 1 512         conv_11[0][0]
# __________________________________________________________________________________________________
# conv_relu_11 (ReLU)             (None, None, None, 1 0           conv_bn_11[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, None, None, 1 0           conv_relu_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, None, None, 1 1152        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, None, None, 1 512         conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (ReLU)          (None, None, None, 1 0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, None, None, 2 32768       conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, None, None, 2 1024        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (ReLU)          (None, None, None, 2 0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, None, None, 2 2304        conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, None, None, 2 1024        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (ReLU)          (None, None, None, 2 0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_13 (Conv2D)             (None, None, None, 2 65536       conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_bn (BatchNormalizati (None, None, None, 2 1024        conv_pw_13[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_relu (ReLU)          (None, None, None, 2 0           conv_pw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_14 (ZeroPadding2D)     (None, None, None, 2 0           conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_14 (DepthwiseConv2D)    (None, None, None, 2 2304        conv_pad_14[0][0]
# __________________________________________________________________________________________________
# conv_dw_14_bn (BatchNormalizati (None, None, None, 2 1024        conv_dw_14[0][0]
# __________________________________________________________________________________________________
# conv_dw_14_relu (ReLU)          (None, None, None, 2 0           conv_dw_14_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_14 (Conv2D)             (None, None, None, 2 65536       conv_dw_14_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_14_bn (BatchNormalizati (None, None, None, 2 1024        conv_pw_14[0][0]
# __________________________________________________________________________________________________
# conv_pw_14_relu (ReLU)          (None, None, None, 2 0           conv_pw_14_bn[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 1 9232        conv_relu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 18448       conv_relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 1 36880       conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 36880       conv_pw_14_relu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, None, None, 1 0           conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, None, None, 1 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, None, None, 1 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, None, None, 1 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 1 2320        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 18464       conv_relu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 2320        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 3 36896       conv_relu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 2320        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 3 73760       conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 1 2320        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 3 73760       conv_pw_14_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 4 0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 4 0           conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 4 0           conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 4 0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, None, None, 4 0           concatenate[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, None, None, 4 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, None, None, 4 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, None, None, 4 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 5196        re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 8 3464        re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 8 3464        re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 5196        re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 6 2598        re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 4 1732        re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 4 1732        re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 2598        re_lu_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, None, 4)      0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, None, 4)      0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, None, 4)      0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None, 4)      0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, None, 2)      0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, None, 2)      0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, None, 2)      0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, None, 2)      0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# face_boxes (Concatenate)        (None, None, 4)      0           reshape_1[0][0]
#                                                                  reshape_3[0][0]
#                                                                  reshape_5[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# face_classes (Concatenate)      (None, None, 2)      0           reshape[0][0]
#                                                                  reshape_2[0][0]
#                                                                  reshape_4[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, None, 6)      0           face_boxes[0][0]
#                                                                  face_classes[0][0]
# ==================================================================================================
# Total params: 1,038,956
# Trainable params: 1,034,636
# Non-trainable params: 4,320
# __________________________________________________________________________________________________

# %% [markdown]
# #### 훈련하기

# %%
class PiecewiseConstantWarmUpDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
    A LearningRateSchedule wiht warm up schedule.
    Modified from tf.keras.optimizers.schedules.PiecewiseConstantDecay
    """

    def __init__(self, boundaries, values, warmup_steps, min_lr,
                 name=None):
        super(PiecewiseConstantWarmUpDecay, self).__init__()

        if len(boundaries) != len(values) - 1:
            raise ValueError(
                    "The length of boundaries should be 1 less than the"
                    "length of values")

        self.boundaries = boundaries
        self.values = values
        self.name = name
        self.warmup_steps = warmup_steps
        self.min_lr = min_lr

    def __call__(self, step):
        with tf.name_scope(self.name or "PiecewiseConstantWarmUp"):
            step = tf.cast(tf.convert_to_tensor(step), tf.float32)
            pred_fn_pairs = []
            warmup_steps = self.warmup_steps
            boundaries = self.boundaries
            values = self.values
            min_lr = self.min_lr

            pred_fn_pairs.append(
                (step <= warmup_steps,
                 lambda: min_lr + step * (values[0] - min_lr) / warmup_steps))
            pred_fn_pairs.append(
                (tf.logical_and(step <= boundaries[0],
                                step > warmup_steps),
                 lambda: tf.constant(values[0])))
            pred_fn_pairs.append(
                (step > boundaries[-1], lambda: tf.constant(values[-1])))

            for low, high, v in zip(boundaries[:-1], boundaries[1:],
                                    values[1:-1]):
                # Need to bind v here; can do this with lambda v=v: ...
                pred = (step > low) & (step <= high)
                pred_fn_pairs.append((pred, lambda: tf.constant(v)))

            # The default isn't needed here because our conditions are mutually
            # exclusive and exhaustive, but tf.case requires it.
            return tf.case(pred_fn_pairs, lambda: tf.constant(values[0]),
                           exclusive=True)

    def get_config(self):
        return {
                "boundaries": self.boundaries,
                "values": self.values,
                "warmup_steps": self.warmup_steps,
                "min_lr": self.min_lr,
                "name": self.name
        }

# %%
def MultiStepWarmUpLR(initial_learning_rate, lr_steps, lr_rate,
                      warmup_steps=0., min_lr=0.,
                      name='MultiStepWarmUpLR'):
    """Multi-steps warm up learning rate scheduler."""
    assert warmup_steps <= lr_steps[0]
    assert min_lr <= initial_learning_rate
    lr_steps_value = [initial_learning_rate]
    for _ in range(len(lr_steps)):
        lr_steps_value.append(lr_steps_value[-1] * lr_rate)
    return PiecewiseConstantWarmUpDecay(
        boundaries=lr_steps, values=lr_steps_value, warmup_steps=warmup_steps,
        min_lr=min_lr)

# %%
def hard_negative_mining(loss, class_truth, neg_ratio):
    """ Hard negative mining algorithm
        to pick up negative examples for back-propagation
        base on classification loss values
    Args:
        loss: list of classification losses of all default boxes (B, num_default)
        class_truth: classification targets (B, num_default)
        neg_ratio: negative / positive ratio
    Returns:
        class_loss: classification loss
        loc_loss: regression loss
    """
    # loss: B x N
    # class_truth: B x N
    pos_idx = class_truth > 0
    num_pos = tf.reduce_sum(tf.dtypes.cast(pos_idx, tf.int32), axis=1)
    num_neg = num_pos * neg_ratio

    rank = tf.argsort(loss, axis=1, direction='DESCENDING')
    rank = tf.argsort(rank, axis=1)
    neg_idx = rank < tf.expand_dims(num_neg, 1)

    return pos_idx, neg_idx

# %%
def MultiBoxLoss(num_class=3, neg_pos_ratio=3.0):
    def multi_loss(y_true, y_pred):
        """ Compute losses for SSD
               regression loss: smooth L1
               classification loss: cross entropy
           Args:
               y_true: [B,N,5]
               y_pred: [B,N,num_class]
               class_pred: outputs of classification heads (B,N, num_classes)
               loc_pred: outputs of regression heads (B,N, 4)
               class_truth: classification targets (B,N)
               loc_truth: regression targets (B,N, 4)
           Returns:
               class_loss: classification loss
               loc_loss: regression loss
       """
        num_batch = tf.shape(y_true)[0]
        num_prior = tf.shape(y_true)[1]
        loc_pred, class_pred = y_pred[..., :4], y_pred[..., 4:]
        loc_truth, class_truth = y_true[..., :4], tf.squeeze(y_true[..., 4:])

        cross_entropy = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

        # compute classification losses without reduction
        temp_loss = cross_entropy(class_truth, class_pred)
        # 2. hard negative mining
        pos_idx, neg_idx = hard_negative_mining(temp_loss, class_truth, neg_pos_ratio)

        # classification loss will consist of positive and negative examples
        cross_entropy = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='sum')

        smooth_l1_loss = tf.keras.losses.Huber(reduction='sum')

        loss_class = cross_entropy(
            class_truth[tf.math.logical_or(pos_idx, neg_idx)],
            class_pred[tf.math.logical_or(pos_idx, neg_idx)])

        # localization loss only consist of positive examples (smooth L1)
        loss_loc = smooth_l1_loss(loc_truth[pos_idx],loc_pred[pos_idx])

        num_pos = tf.reduce_sum(tf.dtypes.cast(pos_idx, tf.float32))

        loss_class = loss_class / num_pos
        loss_loc = loss_loc / num_pos
        return loss_loc, loss_class

    return multi_loss

# %%
global load_t1
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
logger = tf.get_logger()
logger.disabled = True
logger.setLevel(logging.FATAL)

weights_dir = os.getenv('HOME')+'/aiffel/face_detector/checkpoints'
if not os.path.exists(weights_dir):
    os.mkdir(weights_dir)

logging.info("Load configuration...")
label_classes = cfg['labels_list']
logging.info(f"Total image sample:{cfg['dataset_len']},Total classes number:"
             f"{len(label_classes)},classes list:{label_classes}")

logging.info("Compute prior boxes...")
priors, num_cell = prior_box(cfg)
logging.info(f"Prior boxes number:{len(priors)},default anchor box number per feature map cell:{num_cell}") # 4420, [3, 2, 2, 3]

logging.info("Loading dataset...")
train_dataset = load_dataset(cfg, priors, shuffle=True, train=True)

# %%
logging.info("Create Model...")
try:
    model = SsdModel(cfg=cfg, num_cell=num_cell, training=True)
    model.summary()
    tf.keras.utils.plot_model(model, to_file=os.path.join(os.getcwd(), 'model.png'),
                              show_shapes=True, show_layer_names=True)
except Exception as e:
    logging.error(e)
    logging.info("Create network failed.")
# Out:
# Model: "ssd_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 240, 320, 3) 0
# __________________________________________________________________________________________________
# conv_pad_15 (ZeroPadding2D)     (None, 242, 322, 3)  0           input_image[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 120, 160, 16) 432         conv_pad_15[0][0]
# __________________________________________________________________________________________________
# conv_bn_15 (BatchNormalization) (None, 120, 160, 16) 64          conv_15[0][0]
# __________________________________________________________________________________________________
# conv_relu_15 (ReLU)             (None, 120, 160, 16) 0           conv_bn_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 120, 160, 32) 4608        conv_relu_15[0][0]
# __________________________________________________________________________________________________
# conv_bn_16 (BatchNormalization) (None, 120, 160, 32) 128         conv_16[0][0]
# __________________________________________________________________________________________________
# conv_relu_16 (ReLU)             (None, 120, 160, 32) 0           conv_bn_16[0][0]
# __________________________________________________________________________________________________
# conv_pad_17 (ZeroPadding2D)     (None, 122, 162, 32) 0           conv_relu_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 60, 80, 32)   9216        conv_pad_17[0][0]
# __________________________________________________________________________________________________
# conv_bn_17 (BatchNormalization) (None, 60, 80, 32)   128         conv_17[0][0]
# __________________________________________________________________________________________________
# conv_relu_17 (ReLU)             (None, 60, 80, 32)   0           conv_bn_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 60, 80, 32)   9216        conv_relu_17[0][0]
# __________________________________________________________________________________________________
# conv_bn_18 (BatchNormalization) (None, 60, 80, 32)   128         conv_18[0][0]
# __________________________________________________________________________________________________
# conv_relu_18 (ReLU)             (None, 60, 80, 32)   0           conv_bn_18[0][0]
# __________________________________________________________________________________________________
# conv_pad_19 (ZeroPadding2D)     (None, 62, 82, 32)   0           conv_relu_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 30, 40, 64)   18432       conv_pad_19[0][0]
# __________________________________________________________________________________________________
# conv_bn_19 (BatchNormalization) (None, 30, 40, 64)   256         conv_19[0][0]
# __________________________________________________________________________________________________
# conv_relu_19 (ReLU)             (None, 30, 40, 64)   0           conv_bn_19[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 30, 40, 64)   36864       conv_relu_19[0][0]
# __________________________________________________________________________________________________
# conv_bn_20 (BatchNormalization) (None, 30, 40, 64)   256         conv_20[0][0]
# __________________________________________________________________________________________________
# conv_relu_20 (ReLU)             (None, 30, 40, 64)   0           conv_bn_20[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 30, 40, 64)   36864       conv_relu_20[0][0]
# __________________________________________________________________________________________________
# conv_bn_21 (BatchNormalization) (None, 30, 40, 64)   256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_relu_21 (ReLU)             (None, 30, 40, 64)   0           conv_bn_21[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 30, 40, 64)   36864       conv_relu_21[0][0]
# __________________________________________________________________________________________________
# conv_bn_22 (BatchNormalization) (None, 30, 40, 64)   256         conv_22[0][0]
# __________________________________________________________________________________________________
# conv_relu_22 (ReLU)             (None, 30, 40, 64)   0           conv_bn_22[0][0]
# __________________________________________________________________________________________________
# conv_pad_23 (ZeroPadding2D)     (None, 32, 42, 64)   0           conv_relu_22[0][0]
# __________________________________________________________________________________________________
# conv_23 (Conv2D)                (None, 15, 20, 128)  73728       conv_pad_23[0][0]
# __________________________________________________________________________________________________
# conv_bn_23 (BatchNormalization) (None, 15, 20, 128)  512         conv_23[0][0]
# __________________________________________________________________________________________________
# conv_relu_23 (ReLU)             (None, 15, 20, 128)  0           conv_bn_23[0][0]
# __________________________________________________________________________________________________
# conv_24 (Conv2D)                (None, 15, 20, 128)  147456      conv_relu_23[0][0]
# __________________________________________________________________________________________________
# conv_bn_24 (BatchNormalization) (None, 15, 20, 128)  512         conv_24[0][0]
# __________________________________________________________________________________________________
# conv_relu_24 (ReLU)             (None, 15, 20, 128)  0           conv_bn_24[0][0]
# __________________________________________________________________________________________________
# conv_25 (Conv2D)                (None, 15, 20, 128)  147456      conv_relu_24[0][0]
# __________________________________________________________________________________________________
# conv_bn_25 (BatchNormalization) (None, 15, 20, 128)  512         conv_25[0][0]
# __________________________________________________________________________________________________
# conv_relu_25 (ReLU)             (None, 15, 20, 128)  0           conv_bn_25[0][0]
# __________________________________________________________________________________________________
# conv_pad_26 (ZeroPadding2D)     (None, 17, 22, 128)  0           conv_relu_25[0][0]
# __________________________________________________________________________________________________
# conv_dw_26 (DepthwiseConv2D)    (None, 8, 10, 128)   1152        conv_pad_26[0][0]
# __________________________________________________________________________________________________
# conv_dw_26_bn (BatchNormalizati (None, 8, 10, 128)   512         conv_dw_26[0][0]
# __________________________________________________________________________________________________
# conv_dw_26_relu (ReLU)          (None, 8, 10, 128)   0           conv_dw_26_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_26 (Conv2D)             (None, 8, 10, 256)   32768       conv_dw_26_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_26_bn (BatchNormalizati (None, 8, 10, 256)   1024        conv_pw_26[0][0]
# __________________________________________________________________________________________________
# conv_pw_26_relu (ReLU)          (None, 8, 10, 256)   0           conv_pw_26_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_27 (DepthwiseConv2D)    (None, 8, 10, 256)   2304        conv_pw_26_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_27_bn (BatchNormalizati (None, 8, 10, 256)   1024        conv_dw_27[0][0]
# __________________________________________________________________________________________________
# conv_dw_27_relu (ReLU)          (None, 8, 10, 256)   0           conv_dw_27_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_27 (Conv2D)             (None, 8, 10, 256)   65536       conv_dw_27_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_27_bn (BatchNormalizati (None, 8, 10, 256)   1024        conv_pw_27[0][0]
# __________________________________________________________________________________________________
# conv_pw_27_relu (ReLU)          (None, 8, 10, 256)   0           conv_pw_27_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_28 (ZeroPadding2D)     (None, 10, 12, 256)  0           conv_pw_27_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_28 (DepthwiseConv2D)    (None, 4, 5, 256)    2304        conv_pad_28[0][0]
# __________________________________________________________________________________________________
# conv_dw_28_bn (BatchNormalizati (None, 4, 5, 256)    1024        conv_dw_28[0][0]
# __________________________________________________________________________________________________
# conv_dw_28_relu (ReLU)          (None, 4, 5, 256)    0           conv_dw_28_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_28 (Conv2D)             (None, 4, 5, 256)    65536       conv_dw_28_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_28_bn (BatchNormalizati (None, 4, 5, 256)    1024        conv_pw_28[0][0]
# __________________________________________________________________________________________________
# conv_pw_28_relu (ReLU)          (None, 4, 5, 256)    0           conv_pw_28_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 30, 40, 16)   9232        conv_relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 15, 20, 16)   18448       conv_relu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 10, 16)    36880       conv_pw_27_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 4, 5, 16)     36880       conv_pw_28_relu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 30, 40, 16)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 15, 20, 16)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 8, 10, 16)    0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 4, 5, 16)     0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 30, 40, 16)   2320        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 30, 40, 32)   18464       conv_relu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 15, 20, 16)   2320        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 15, 20, 32)   36896       conv_relu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 10, 16)    2320        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 10, 32)    73760       conv_pw_27_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 5, 16)     2320        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 5, 32)     73760       conv_pw_28_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 30, 40, 48)   0           conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 15, 20, 48)   0           conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8, 10, 48)    0           conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 4, 5, 48)     0           conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 30, 40, 48)   0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 15, 20, 48)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 8, 10, 48)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 4, 5, 48)     0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 30, 40, 12)   5196        re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 15, 20, 8)    3464        re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 10, 8)     3464        re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 5, 12)     5196        re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 30, 40, 6)    2598        re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 15, 20, 4)    1732        re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 10, 4)     1732        re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 5, 6)      2598        re_lu_7[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, None, 4)      0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, None, 4)      0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, None, 4)      0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, None, 4)      0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, None, 2)      0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, None, 2)      0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, None, 2)      0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, None, 2)      0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# face_boxes (Concatenate)        (None, None, 4)      0           reshape_9[0][0]
#                                                                  reshape_11[0][0]
#                                                                  reshape_13[0][0]
#                                                                  reshape_15[0][0]
# __________________________________________________________________________________________________
# face_classes (Concatenate)      (None, None, 2)      0           reshape_8[0][0]
#                                                                  reshape_10[0][0]
#                                                                  reshape_12[0][0]
#                                                                  reshape_14[0][0]
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, None, 6)      0           face_boxes[0][0]
#                                                                  face_classes[0][0]
# ==================================================================================================
# Total params: 1,038,956
# Trainable params: 1,034,636
# Non-trainable params: 4,320
# __________________________________________________________________________________________________
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
if cfg['resume']:
    # Training from latest weights
    paths = [os.path.join(weights_dir, path)
             for path in os.listdir(weights_dir)]
    latest = sorted(paths, key=os.path.getmtime)[-1]
    model.load_weights(latest)
    init_epoch = int(os.path.splitext(latest)[0][-3:])

else:
    init_epoch = -1

steps_per_epoch = cfg['dataset_len'] // cfg['batch_size']
logging.info(f"steps_per_epoch:{steps_per_epoch}")

learning_rate = MultiStepWarmUpLR(
    initial_learning_rate=cfg['init_lr'],
    lr_steps=[e * steps_per_epoch for e in cfg['lr_decay_epoch']],
    lr_rate=cfg['lr_rate'],
    warmup_steps=cfg['warmup_epoch'] * steps_per_epoch,
    min_lr=cfg['min_lr'])

optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=cfg['momentum'], nesterov=True)
multi_loss = MultiBoxLoss(num_class=len(label_classes), neg_pos_ratio=3)
train_log_dir = 'logs/train'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)

# %%
@tf.function
def train_step(inputs, labels):
    with tf.GradientTape() as tape:
        predictions = model(inputs, training=True)
        losses = {}
        losses['reg'] = tf.reduce_sum(model.losses)  #unused. Init for redefine network
        losses['loc'], losses['class'] = multi_loss(labels, predictions)
        total_loss = tf.add_n([l for l in losses.values()])

    grads = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

    return total_loss, losses

# %%
import time

for epoch in range(init_epoch+1,cfg['epoch']):
    try:
        start = time.time()
        avg_loss = 0.0
        for step, (inputs, labels) in enumerate(train_dataset.take(steps_per_epoch)):

            load_t0 = time.time()
            total_loss, losses = train_step(inputs, labels)
            avg_loss = (avg_loss * step + total_loss.numpy()) / (step + 1)
            load_t1 = time.time()
            batch_time = load_t1 - load_t0

            steps =steps_per_epoch*epoch+step
            with train_summary_writer.as_default():
                tf.summary.scalar('loss/total_loss', total_loss, step=steps)
                for k, l in losses.items():
                    tf.summary.scalar('loss/{}'.format(k), l, step=steps)
                tf.summary.scalar('learning_rate', optimizer.lr(steps), step=steps)

            print(f"\rEpoch: {epoch + 1}/{cfg['epoch']} | Batch {step + 1}/{steps_per_epoch} | Batch time {batch_time:.3f} || Loss: {total_loss:.6f} | loc loss:{losses['loc']:.6f} | class loss:{losses['class']:.6f} ",end = '',flush=True)

        print(f"\nEpoch: {epoch + 1}/{cfg['epoch']}  | Epoch time {(load_t1 - start):.3f} || Average Loss: {avg_loss:.6f}")

        with train_summary_writer.as_default():
            tf.summary.scalar('loss/avg_loss',avg_loss,step=epoch)

        if (epoch + 1) % cfg['save_freq'] == 0:
            filepath = os.path.join(weights_dir, f'weights_epoch_{(epoch + 1):03d}.h5')
            model.save_weights(filepath)
            if os.path.exists(filepath):
                print(f">>>>>>>>>>Save weights file at {filepath}<<<<<<<<<<")

    except KeyboardInterrupt:
        print('interrupted')
        exit(0)
# Out:
# Epoch: 1/200 | Batch 201/201 | Batch time 0.114 || Loss: 10.225706 | loc loss:7.912208 | class loss:2.313498
# Epoch: 1/200  | Epoch time 38.572 || Average Loss: inf
# Epoch: 2/200 | Batch 201/201 | Batch time 0.147 || Loss: 6.582943 | loc loss:3.869356 | class loss:2.713587
# Epoch: 2/200  | Epoch time 31.866 || Average Loss: inf
# Epoch: 3/200 | Batch 201/201 | Batch time 0.104 || Loss: 6.310629 | loc loss:4.195611 | class loss:2.115018
# Epoch: 3/200  | Epoch time 31.982 || Average Loss: inf
# Epoch: 4/200 | Batch 201/201 | Batch time 0.095 || Loss: 6.193707 | loc loss:4.118285 | class loss:2.075422
# Epoch: 4/200  | Epoch time 32.486 || Average Loss: inf
# Epoch: 5/200 | Batch 201/201 | Batch time 0.101 || Loss: 5.485166 | loc loss:3.561135 | class loss:1.924031
# Epoch: 5/200  | Epoch time 33.056 || Average Loss: inf
# Epoch: 6/200 | Batch 201/201 | Batch time 0.090 || Loss: 7.108528 | loc loss:4.813289 | class loss:2.295238
# Epoch: 6/200  | Epoch time 32.961 || Average Loss: inf
# Epoch: 7/200 | Batch 201/201 | Batch time 0.145 || Loss: 5.528910 | loc loss:3.789160 | class loss:1.739750
# Epoch: 7/200  | Epoch time 33.872 || Average Loss: inf
# Epoch: 8/200 | Batch 201/201 | Batch time 0.117 || Loss: 6.100998 | loc loss:4.217944 | class loss:1.883055
# Epoch: 8/200  | Epoch time 33.195 || Average Loss: inf
# Epoch: 9/200 | Batch 201/201 | Batch time 0.113 || Loss: 5.359633 | loc loss:3.636472 | class loss:1.723161
# Epoch: 9/200  | Epoch time 33.567 || Average Loss: inf
# Epoch: 10/200 | Batch 201/201 | Batch time 0.096 || Loss: 5.890995 | loc loss:4.378105 | class loss:1.512891
# Epoch: 10/200  | Epoch time 32.675 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_010.h5<<<<<<<<<<
# Epoch: 11/200 | Batch 201/201 | Batch time 0.085 || Loss: 4.811783 | loc loss:3.115640 | class loss:1.696143
# Epoch: 11/200  | Epoch time 33.214 || Average Loss: inf
# Epoch: 12/200 | Batch 201/201 | Batch time 0.109 || Loss: 6.097959 | loc loss:4.300372 | class loss:1.797587
# Epoch: 12/200  | Epoch time 32.622 || Average Loss: inf
# Epoch: 13/200 | Batch 201/201 | Batch time 0.128 || Loss: 6.247791 | loc loss:4.485558 | class loss:1.762233
# Epoch: 13/200  | Epoch time 33.017 || Average Loss: inf
# Epoch: 14/200 | Batch 201/201 | Batch time 0.124 || Loss: 5.260019 | loc loss:3.748604 | class loss:1.511415
# Epoch: 14/200  | Epoch time 33.224 || Average Loss: inf
# Epoch: 15/200 | Batch 201/201 | Batch time 0.122 || Loss: 6.139943 | loc loss:4.489028 | class loss:1.650914
# Epoch: 15/200  | Epoch time 32.755 || Average Loss: inf
# Epoch: 16/200 | Batch 201/201 | Batch time 0.094 || Loss: 4.553358 | loc loss:3.047707 | class loss:1.505651
# Epoch: 16/200  | Epoch time 32.820 || Average Loss: inf
# Epoch: 17/200 | Batch 201/201 | Batch time 0.091 || Loss: 4.556726 | loc loss:3.247425 | class loss:1.309301
# Epoch: 17/200  | Epoch time 31.955 || Average Loss: inf
# Epoch: 18/200 | Batch 201/201 | Batch time 0.124 || Loss: 6.701467 | loc loss:5.097109 | class loss:1.604358
# Epoch: 18/200  | Epoch time 31.608 || Average Loss: inf
# Epoch: 19/200 | Batch 201/201 | Batch time 0.117 || Loss: 4.956143 | loc loss:3.567104 | class loss:1.389040
# Epoch: 19/200  | Epoch time 28.630 || Average Loss: inf
# Epoch: 20/200 | Batch 201/201 | Batch time 0.119 || Loss: 3.775129 | loc loss:2.492566 | class loss:1.282563
# Epoch: 20/200  | Epoch time 28.653 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_020.h5<<<<<<<<<<
# Epoch: 21/200 | Batch 201/201 | Batch time 0.128 || Loss: 5.830639 | loc loss:4.409374 | class loss:1.421265
# Epoch: 21/200  | Epoch time 30.112 || Average Loss: inf
# Epoch: 22/200 | Batch 201/201 | Batch time 0.098 || Loss: 4.782962 | loc loss:3.262989 | class loss:1.519973
# Epoch: 22/200  | Epoch time 30.640 || Average Loss: inf
# Epoch: 23/200 | Batch 201/201 | Batch time 0.090 || Loss: 3.868026 | loc loss:2.557172 | class loss:1.310855
# Epoch: 23/200  | Epoch time 29.823 || Average Loss: inf
# Epoch: 24/200 | Batch 201/201 | Batch time 0.090 || Loss: 4.635600 | loc loss:3.245135 | class loss:1.390465
# Epoch: 24/200  | Epoch time 29.713 || Average Loss: inf
# Epoch: 25/200 | Batch 201/201 | Batch time 0.119 || Loss: 5.714467 | loc loss:4.387045 | class loss:1.327422
# Epoch: 25/200  | Epoch time 29.996 || Average Loss: inf
# Epoch: 26/200 | Batch 201/201 | Batch time 0.093 || Loss: 6.417590 | loc loss:4.907787 | class loss:1.509803
# Epoch: 26/200  | Epoch time 31.085 || Average Loss: inf
# Epoch: 27/200 | Batch 201/201 | Batch time 0.090 || Loss: 4.568149 | loc loss:3.145365 | class loss:1.422783
# Epoch: 27/200  | Epoch time 31.371 || Average Loss: inf
# Epoch: 28/200 | Batch 201/201 | Batch time 0.113 || Loss: 6.130167 | loc loss:4.554066 | class loss:1.576102
# Epoch: 28/200  | Epoch time 30.517 || Average Loss: inf
# Epoch: 29/200 | Batch 201/201 | Batch time 0.119 || Loss: 5.107222 | loc loss:3.589685 | class loss:1.517537
# Epoch: 29/200  | Epoch time 30.378 || Average Loss: inf
# Epoch: 30/200 | Batch 201/201 | Batch time 0.148 || Loss: 4.888175 | loc loss:3.483123 | class loss:1.405052
# Epoch: 30/200  | Epoch time 29.605 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_030.h5<<<<<<<<<<
# Epoch: 31/200 | Batch 201/201 | Batch time 0.109 || Loss: 4.510323 | loc loss:3.243602 | class loss:1.266721
# Epoch: 31/200  | Epoch time 29.673 || Average Loss: inf
# Epoch: 32/200 | Batch 201/201 | Batch time 0.130 || Loss: 5.400050 | loc loss:4.000905 | class loss:1.399145
# Epoch: 32/200  | Epoch time 29.623 || Average Loss: inf
# Epoch: 33/200 | Batch 201/201 | Batch time 0.071 || Loss: 4.629002 | loc loss:3.180815 | class loss:1.448187
# Epoch: 33/200  | Epoch time 29.388 || Average Loss: inf
# Epoch: 34/200 | Batch 201/201 | Batch time 0.126 || Loss: 4.141605 | loc loss:2.925752 | class loss:1.215853
# Epoch: 34/200  | Epoch time 29.390 || Average Loss: inf
# Epoch: 35/200 | Batch 201/201 | Batch time 0.114 || Loss: 4.801262 | loc loss:3.637685 | class loss:1.163578
# Epoch: 35/200  | Epoch time 29.030 || Average Loss: inf
# Epoch: 36/200 | Batch 201/201 | Batch time 0.112 || Loss: 5.653883 | loc loss:4.160057 | class loss:1.493826
# Epoch: 36/200  | Epoch time 29.246 || Average Loss: inf
# Epoch: 37/200 | Batch 201/201 | Batch time 0.103 || Loss: 3.919990 | loc loss:2.739240 | class loss:1.180750
# Epoch: 37/200  | Epoch time 29.964 || Average Loss: inf
# Epoch: 38/200 | Batch 201/201 | Batch time 0.097 || Loss: 3.720109 | loc loss:2.616151 | class loss:1.103958
# Epoch: 38/200  | Epoch time 30.229 || Average Loss: inf
# Epoch: 39/200 | Batch 201/201 | Batch time 0.112 || Loss: 3.665074 | loc loss:2.518060 | class loss:1.147013
# Epoch: 39/200  | Epoch time 29.743 || Average Loss: inf
# Epoch: 40/200 | Batch 201/201 | Batch time 0.120 || Loss: 4.797007 | loc loss:3.520407 | class loss:1.276600
# Epoch: 40/200  | Epoch time 29.651 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_040.h5<<<<<<<<<<
# Epoch: 41/200 | Batch 201/201 | Batch time 0.091 || Loss: 3.683578 | loc loss:2.430605 | class loss:1.252974
# Epoch: 41/200  | Epoch time 31.090 || Average Loss: inf
# Epoch: 42/200 | Batch 201/201 | Batch time 0.084 || Loss: 5.198219 | loc loss:3.905978 | class loss:1.292241
# Epoch: 42/200  | Epoch time 31.294 || Average Loss: inf
# Epoch: 43/200 | Batch 201/201 | Batch time 0.122 || Loss: 4.444460 | loc loss:3.336756 | class loss:1.107704
# Epoch: 43/200  | Epoch time 31.136 || Average Loss: inf
# Epoch: 44/200 | Batch 201/201 | Batch time 0.104 || Loss: 5.829782 | loc loss:4.656608 | class loss:1.173175
# Epoch: 44/200  | Epoch time 30.554 || Average Loss: inf
# Epoch: 45/200 | Batch 201/201 | Batch time 0.114 || Loss: inf | loc loss:inf | class loss:1.174699 :1.286433
# Epoch: 45/200  | Epoch time 30.627 || Average Loss: inf
# Epoch: 46/200 | Batch 201/201 | Batch time 0.118 || Loss: 5.365418 | loc loss:4.272452 | class loss:1.092966
# Epoch: 46/200  | Epoch time 29.996 || Average Loss: inf
# Epoch: 47/200 | Batch 201/201 | Batch time 0.109 || Loss: 4.243477 | loc loss:3.100808 | class loss:1.142669
# Epoch: 47/200  | Epoch time 29.908 || Average Loss: inf
# Epoch: 48/200 | Batch 201/201 | Batch time 0.092 || Loss: 4.619521 | loc loss:3.504890 | class loss:1.114631
# Epoch: 48/200  | Epoch time 30.584 || Average Loss: inf
# Epoch: 49/200 | Batch 201/201 | Batch time 0.115 || Loss: 4.065234 | loc loss:2.882820 | class loss:1.182413
# Epoch: 49/200  | Epoch time 29.680 || Average Loss: inf
# Epoch: 50/200 | Batch 201/201 | Batch time 0.129 || Loss: 5.196493 | loc loss:3.897180 | class loss:1.299313
# Epoch: 50/200  | Epoch time 29.453 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_050.h5<<<<<<<<<<
# Epoch: 51/200 | Batch 201/201 | Batch time 0.115 || Loss: 3.829526 | loc loss:2.899995 | class loss:0.929531
# Epoch: 51/200  | Epoch time 28.762 || Average Loss: inf
# Epoch: 52/200 | Batch 201/201 | Batch time 0.096 || Loss: 4.863959 | loc loss:3.743711 | class loss:1.120249
# Epoch: 52/200  | Epoch time 29.654 || Average Loss: inf
# Epoch: 53/200 | Batch 201/201 | Batch time 0.116 || Loss: 4.940797 | loc loss:3.663035 | class loss:1.277762
# Epoch: 53/200  | Epoch time 29.715 || Average Loss: inf
# Epoch: 54/200 | Batch 201/201 | Batch time 0.117 || Loss: 3.645721 | loc loss:2.567118 | class loss:1.078603
# Epoch: 54/200  | Epoch time 29.959 || Average Loss: inf
# Epoch: 55/200 | Batch 201/201 | Batch time 0.091 || Loss: 5.598591 | loc loss:4.573394 | class loss:1.025197
# Epoch: 55/200  | Epoch time 30.312 || Average Loss: inf
# Epoch: 56/200 | Batch 201/201 | Batch time 0.099 || Loss: 4.895571 | loc loss:3.696775 | class loss:1.198796
# Epoch: 56/200  | Epoch time 30.418 || Average Loss: inf
# Epoch: 57/200 | Batch 201/201 | Batch time 0.131 || Loss: 4.276668 | loc loss:3.212593 | class loss:1.064074
# Epoch: 57/200  | Epoch time 29.967 || Average Loss: inf
# Epoch: 58/200 | Batch 201/201 | Batch time 0.100 || Loss: 4.287017 | loc loss:3.257641 | class loss:1.029376
# Epoch: 58/200  | Epoch time 30.298 || Average Loss: inf
# Epoch: 59/200 | Batch 201/201 | Batch time 0.129 || Loss: 4.488831 | loc loss:3.485079 | class loss:1.003751
# Epoch: 59/200  | Epoch time 30.511 || Average Loss: inf
# Epoch: 60/200 | Batch 201/201 | Batch time 0.099 || Loss: 4.988013 | loc loss:4.006986 | class loss:0.981027
# Epoch: 60/200  | Epoch time 31.359 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_060.h5<<<<<<<<<<
# Epoch: 61/200 | Batch 201/201 | Batch time 0.090 || Loss: 6.158280 | loc loss:4.906290 | class loss:1.251990
# Epoch: 61/200  | Epoch time 29.931 || Average Loss: inf
# Epoch: 62/200 | Batch 201/201 | Batch time 0.085 || Loss: 5.163589 | loc loss:3.944031 | class loss:1.219558
# Epoch: 62/200  | Epoch time 29.963 || Average Loss: inf
# Epoch: 63/200 | Batch 201/201 | Batch time 0.114 || Loss: 6.810884 | loc loss:5.742435 | class loss:1.068448
# Epoch: 63/200  | Epoch time 30.326 || Average Loss: inf
# Epoch: 64/200 | Batch 201/201 | Batch time 0.107 || Loss: 3.799560 | loc loss:2.657523 | class loss:1.142037
# Epoch: 64/200  | Epoch time 29.489 || Average Loss: inf
# Epoch: 65/200 | Batch 201/201 | Batch time 0.102 || Loss: 6.959148 | loc loss:5.617157 | class loss:1.341992
# Epoch: 65/200  | Epoch time 30.630 || Average Loss: inf
# Epoch: 66/200 | Batch 201/201 | Batch time 0.125 || Loss: 3.525634 | loc loss:2.400334 | class loss:1.125300
# Epoch: 66/200  | Epoch time 30.231 || Average Loss: inf
# Epoch: 67/200 | Batch 201/201 | Batch time 0.103 || Loss: 5.292506 | loc loss:4.122357 | class loss:1.170149
# Epoch: 67/200  | Epoch time 29.681 || Average Loss: inf
# Epoch: 68/200 | Batch 201/201 | Batch time 0.093 || Loss: 3.499033 | loc loss:2.261394 | class loss:1.237639
# Epoch: 68/200  | Epoch time 30.357 || Average Loss: inf
# Epoch: 69/200 | Batch 201/201 | Batch time 0.097 || Loss: 4.763145 | loc loss:3.639462 | class loss:1.123684
# Epoch: 69/200  | Epoch time 31.581 || Average Loss: inf
# Epoch: 70/200 | Batch 201/201 | Batch time 0.121 || Loss: 3.930273 | loc loss:2.936758 | class loss:0.993515
# Epoch: 70/200  | Epoch time 31.470 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_070.h5<<<<<<<<<<
# Epoch: 71/200 | Batch 201/201 | Batch time 0.090 || Loss: 5.606471 | loc loss:4.395578 | class loss:1.210892
# Epoch: 71/200  | Epoch time 31.702 || Average Loss: inf
# Epoch: 72/200 | Batch 201/201 | Batch time 0.088 || Loss: 5.053891 | loc loss:3.885236 | class loss:1.168655
# Epoch: 72/200  | Epoch time 32.978 || Average Loss: inf
# Epoch: 73/200 | Batch 201/201 | Batch time 0.088 || Loss: 2.758934 | loc loss:1.619915 | class loss:1.139019
# Epoch: 73/200  | Epoch time 33.270 || Average Loss: inf
# Epoch: 74/200 | Batch 201/201 | Batch time 0.125 || Loss: 4.883751 | loc loss:3.703187 | class loss:1.180564
# Epoch: 74/200  | Epoch time 33.520 || Average Loss: inf
# Epoch: 75/200 | Batch 201/201 | Batch time 0.090 || Loss: 4.689473 | loc loss:3.496131 | class loss:1.193342
# Epoch: 75/200  | Epoch time 33.051 || Average Loss: inf
# Epoch: 76/200 | Batch 201/201 | Batch time 0.100 || Loss: 4.921191 | loc loss:3.896112 | class loss:1.025079
# Epoch: 76/200  | Epoch time 32.479 || Average Loss: inf
# Epoch: 77/200 | Batch 201/201 | Batch time 0.103 || Loss: 4.674335 | loc loss:3.510271 | class loss:1.164064
# Epoch: 77/200  | Epoch time 32.766 || Average Loss: inf
# Epoch: 78/200 | Batch 201/201 | Batch time 0.148 || Loss: 4.593406 | loc loss:3.341455 | class loss:1.251951
# Epoch: 78/200  | Epoch time 33.517 || Average Loss: inf
# Epoch: 79/200 | Batch 201/201 | Batch time 0.134 || Loss: 3.589495 | loc loss:2.599171 | class loss:0.990325
# Epoch: 79/200  | Epoch time 32.841 || Average Loss: inf
# Epoch: 80/200 | Batch 201/201 | Batch time 0.103 || Loss: 4.078200 | loc loss:2.972552 | class loss:1.105648
# Epoch: 80/200  | Epoch time 33.011 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_080.h5<<<<<<<<<<
# Epoch: 81/200 | Batch 201/201 | Batch time 0.098 || Loss: 3.538198 | loc loss:2.401307 | class loss:1.136891
# Epoch: 81/200  | Epoch time 32.647 || Average Loss: inf
# Epoch: 82/200 | Batch 201/201 | Batch time 0.117 || Loss: 6.361694 | loc loss:5.130862 | class loss:1.230832
# Epoch: 82/200  | Epoch time 32.747 || Average Loss: inf
# Epoch: 83/200 | Batch 201/201 | Batch time 0.131 || Loss: 5.198371 | loc loss:4.171940 | class loss:1.026431
# Epoch: 83/200  | Epoch time 33.719 || Average Loss: inf
# Epoch: 84/200 | Batch 201/201 | Batch time 0.127 || Loss: inf | loc loss:inf | class loss:0.993062 :1.173125
# Epoch: 84/200  | Epoch time 33.193 || Average Loss: inf
# Epoch: 85/200 | Batch 201/201 | Batch time 0.105 || Loss: 3.914790 | loc loss:2.745948 | class loss:1.168842
# Epoch: 85/200  | Epoch time 33.717 || Average Loss: inf
# Epoch: 86/200 | Batch 201/201 | Batch time 0.111 || Loss: inf | loc loss:inf | class loss:1.161567 :1.338020
# Epoch: 86/200  | Epoch time 33.334 || Average Loss: inf
# Epoch: 87/200 | Batch 201/201 | Batch time 0.110 || Loss: 4.460954 | loc loss:3.237528 | class loss:1.223426
# Epoch: 87/200  | Epoch time 33.169 || Average Loss: inf
# Epoch: 88/200 | Batch 201/201 | Batch time 0.104 || Loss: 4.841682 | loc loss:3.531167 | class loss:1.310515
# Epoch: 88/200  | Epoch time 33.060 || Average Loss: inf
# Epoch: 89/200 | Batch 201/201 | Batch time 0.089 || Loss: 3.909961 | loc loss:2.700211 | class loss:1.209750
# Epoch: 89/200  | Epoch time 33.491 || Average Loss: inf
# Epoch: 90/200 | Batch 201/201 | Batch time 0.096 || Loss: 6.403354 | loc loss:5.286507 | class loss:1.116846
# Epoch: 90/200  | Epoch time 33.246 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_090.h5<<<<<<<<<<
# Epoch: 91/200 | Batch 201/201 | Batch time 0.110 || Loss: 4.485503 | loc loss:3.380584 | class loss:1.104919
# Epoch: 91/200  | Epoch time 32.697 || Average Loss: inf
# Epoch: 92/200 | Batch 201/201 | Batch time 0.119 || Loss: 5.327652 | loc loss:4.084312 | class loss:1.243340
# Epoch: 92/200  | Epoch time 33.085 || Average Loss: inf
# Epoch: 93/200 | Batch 201/201 | Batch time 0.099 || Loss: 4.552559 | loc loss:3.601019 | class loss:0.951540
# Epoch: 93/200  | Epoch time 31.923 || Average Loss: inf
# Epoch: 94/200 | Batch 201/201 | Batch time 0.084 || Loss: 4.495919 | loc loss:3.227288 | class loss:1.268631
# Epoch: 94/200  | Epoch time 33.184 || Average Loss: inf
# Epoch: 95/200 | Batch 201/201 | Batch time 0.141 || Loss: 2.821021 | loc loss:1.748881 | class loss:1.072140
# Epoch: 95/200  | Epoch time 32.480 || Average Loss: inf
# Epoch: 96/200 | Batch 201/201 | Batch time 0.144 || Loss: 3.707474 | loc loss:2.684107 | class loss:1.023368
# Epoch: 96/200  | Epoch time 33.236 || Average Loss: inf
# Epoch: 97/200 | Batch 201/201 | Batch time 0.096 || Loss: 4.807287 | loc loss:3.772456 | class loss:1.034831
# Epoch: 97/200  | Epoch time 33.138 || Average Loss: inf
# Epoch: 98/200 | Batch 201/201 | Batch time 0.109 || Loss: 4.446376 | loc loss:3.266304 | class loss:1.180072
# Epoch: 98/200  | Epoch time 32.814 || Average Loss: inf
# Epoch: 99/200 | Batch 201/201 | Batch time 0.105 || Loss: 4.451589 | loc loss:3.394191 | class loss:1.057397
# Epoch: 99/200  | Epoch time 33.205 || Average Loss: inf
# Epoch: 100/200 | Batch 201/201 | Batch time 0.118 || Loss: 4.450153 | loc loss:3.441890 | class loss:1.008263
# Epoch: 100/200  | Epoch time 32.837 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_100.h5<<<<<<<<<<
# Epoch: 101/200 | Batch 201/201 | Batch time 0.095 || Loss: 4.226624 | loc loss:3.337708 | class loss:0.888916
# Epoch: 101/200  | Epoch time 32.747 || Average Loss: inf
# Epoch: 102/200 | Batch 201/201 | Batch time 0.103 || Loss: 3.623326 | loc loss:2.406342 | class loss:1.216985
# Epoch: 102/200  | Epoch time 32.767 || Average Loss: inf
# Epoch: 103/200 | Batch 201/201 | Batch time 0.121 || Loss: 4.198842 | loc loss:3.109663 | class loss:1.089178
# Epoch: 103/200  | Epoch time 32.678 || Average Loss: inf
# Epoch: 104/200 | Batch 201/201 | Batch time 0.088 || Loss: 4.720529 | loc loss:3.499121 | class loss:1.221407
# Epoch: 104/200  | Epoch time 32.335 || Average Loss: inf
# Epoch: 105/200 | Batch 201/201 | Batch time 0.120 || Loss: inf | loc loss:inf | class loss:1.040038 :1.352704
# Epoch: 105/200  | Epoch time 32.776 || Average Loss: inf
# Epoch: 106/200 | Batch 201/201 | Batch time 0.089 || Loss: 3.915295 | loc loss:2.719886 | class loss:1.195409
# Epoch: 106/200  | Epoch time 33.292 || Average Loss: inf
# Epoch: 107/200 | Batch 201/201 | Batch time 0.080 || Loss: 4.262341 | loc loss:3.184692 | class loss:1.077648
# Epoch: 107/200  | Epoch time 32.862 || Average Loss: inf
# Epoch: 108/200 | Batch 201/201 | Batch time 0.108 || Loss: 4.066428 | loc loss:2.973838 | class loss:1.092590
# Epoch: 108/200  | Epoch time 33.158 || Average Loss: inf
# Epoch: 109/200 | Batch 201/201 | Batch time 0.097 || Loss: 5.711190 | loc loss:4.551911 | class loss:1.159279
# Epoch: 109/200  | Epoch time 32.648 || Average Loss: inf
# Epoch: 110/200 | Batch 201/201 | Batch time 0.097 || Loss: 3.126156 | loc loss:2.102346 | class loss:1.023809
# Epoch: 110/200  | Epoch time 33.230 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_110.h5<<<<<<<<<<
# Epoch: 111/200 | Batch 201/201 | Batch time 0.121 || Loss: 3.975988 | loc loss:3.005264 | class loss:0.970724
# Epoch: 111/200  | Epoch time 33.337 || Average Loss: inf
# Epoch: 112/200 | Batch 201/201 | Batch time 0.153 || Loss: 4.823590 | loc loss:3.768514 | class loss:1.055076
# Epoch: 112/200  | Epoch time 33.361 || Average Loss: inf
# Epoch: 113/200 | Batch 201/201 | Batch time 0.083 || Loss: 4.027638 | loc loss:2.979061 | class loss:1.048577
# Epoch: 113/200  | Epoch time 33.355 || Average Loss: inf
# Epoch: 114/200 | Batch 201/201 | Batch time 0.144 || Loss: 5.323903 | loc loss:4.224050 | class loss:1.099853
# Epoch: 114/200  | Epoch time 33.228 || Average Loss: inf
# Epoch: 115/200 | Batch 201/201 | Batch time 0.101 || Loss: 4.894051 | loc loss:3.892106 | class loss:1.001945
# Epoch: 115/200  | Epoch time 33.628 || Average Loss: inf
# Epoch: 116/200 | Batch 201/201 | Batch time 0.120 || Loss: 4.859008 | loc loss:3.675769 | class loss:1.183240
# Epoch: 116/200  | Epoch time 33.383 || Average Loss: inf
# Epoch: 117/200 | Batch 201/201 | Batch time 0.096 || Loss: 4.980717 | loc loss:4.048742 | class loss:0.931976
# Epoch: 117/200  | Epoch time 33.031 || Average Loss: inf
# Epoch: 118/200 | Batch 201/201 | Batch time 0.132 || Loss: 5.599852 | loc loss:4.397081 | class loss:1.202770
# Epoch: 118/200  | Epoch time 32.981 || Average Loss: inf
# Epoch: 119/200 | Batch 201/201 | Batch time 0.140 || Loss: 4.126451 | loc loss:3.196074 | class loss:0.930377
# Epoch: 119/200  | Epoch time 33.642 || Average Loss: inf
# Epoch: 120/200 | Batch 201/201 | Batch time 0.107 || Loss: 4.759223 | loc loss:3.625842 | class loss:1.133381
# Epoch: 120/200  | Epoch time 33.198 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_120.h5<<<<<<<<<<
# Epoch: 121/200 | Batch 201/201 | Batch time 0.091 || Loss: inf | loc loss:inf | class loss:1.219957 :1.367411
# Epoch: 121/200  | Epoch time 33.265 || Average Loss: inf
# Epoch: 122/200 | Batch 201/201 | Batch time 0.102 || Loss: 4.733851 | loc loss:3.646121 | class loss:1.087731
# Epoch: 122/200  | Epoch time 33.120 || Average Loss: inf
# Epoch: 123/200 | Batch 201/201 | Batch time 0.119 || Loss: 4.380153 | loc loss:3.241737 | class loss:1.138416
# Epoch: 123/200  | Epoch time 33.563 || Average Loss: inf
# Epoch: 124/200 | Batch 201/201 | Batch time 0.101 || Loss: 4.564101 | loc loss:3.575558 | class loss:0.988543
# Epoch: 124/200  | Epoch time 33.127 || Average Loss: inf
# Epoch: 125/200 | Batch 201/201 | Batch time 0.114 || Loss: 4.826383 | loc loss:3.736834 | class loss:1.089548
# Epoch: 125/200  | Epoch time 33.229 || Average Loss: inf
# Epoch: 126/200 | Batch 201/201 | Batch time 0.154 || Loss: 4.344101 | loc loss:3.479353 | class loss:0.864748
# Epoch: 126/200  | Epoch time 32.919 || Average Loss: inf
# Epoch: 127/200 | Batch 201/201 | Batch time 0.119 || Loss: 3.460329 | loc loss:2.407871 | class loss:1.052457
# Epoch: 127/200  | Epoch time 33.129 || Average Loss: inf
# Epoch: 128/200 | Batch 201/201 | Batch time 0.107 || Loss: 4.904847 | loc loss:3.833302 | class loss:1.071545
# Epoch: 128/200  | Epoch time 32.680 || Average Loss: inf
# Epoch: 129/200 | Batch 201/201 | Batch time 0.143 || Loss: 4.292063 | loc loss:3.236043 | class loss:1.056019
# Epoch: 129/200  | Epoch time 32.982 || Average Loss: inf
# Epoch: 130/200 | Batch 201/201 | Batch time 0.103 || Loss: 4.820168 | loc loss:3.779845 | class loss:1.040323
# Epoch: 130/200  | Epoch time 30.913 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_130.h5<<<<<<<<<<
# Epoch: 131/200 | Batch 201/201 | Batch time 0.098 || Loss: 5.323081 | loc loss:4.270661 | class loss:1.052420
# Epoch: 131/200  | Epoch time 32.646 || Average Loss: inf
# Epoch: 132/200 | Batch 201/201 | Batch time 0.090 || Loss: 5.202579 | loc loss:4.134092 | class loss:1.068486
# Epoch: 132/200  | Epoch time 32.413 || Average Loss: inf
# Epoch: 133/200 | Batch 201/201 | Batch time 0.100 || Loss: 5.192205 | loc loss:4.143298 | class loss:1.048907
# Epoch: 133/200  | Epoch time 29.418 || Average Loss: inf
# Epoch: 134/200 | Batch 201/201 | Batch time 0.099 || Loss: 3.358129 | loc loss:2.471392 | class loss:0.886736
# Epoch: 134/200  | Epoch time 27.736 || Average Loss: inf
# Epoch: 135/200 | Batch 201/201 | Batch time 0.115 || Loss: 4.792542 | loc loss:3.587722 | class loss:1.204819
# Epoch: 135/200  | Epoch time 28.518 || Average Loss: inf
# Epoch: 136/200 | Batch 201/201 | Batch time 0.112 || Loss: 4.743483 | loc loss:3.657290 | class loss:1.086192
# Epoch: 136/200  | Epoch time 27.958 || Average Loss: inf
# Epoch: 137/200 | Batch 201/201 | Batch time 0.100 || Loss: 4.170064 | loc loss:3.049420 | class loss:1.120645
# Epoch: 137/200  | Epoch time 28.243 || Average Loss: inf
# Epoch: 138/200 | Batch 201/201 | Batch time 0.122 || Loss: 2.897199 | loc loss:1.801988 | class loss:1.095211
# Epoch: 138/200  | Epoch time 29.120 || Average Loss: inf
# Epoch: 139/200 | Batch 201/201 | Batch time 0.091 || Loss: 4.314815 | loc loss:3.271070 | class loss:1.043745
# Epoch: 139/200  | Epoch time 28.225 || Average Loss: inf
# Epoch: 140/200 | Batch 201/201 | Batch time 0.091 || Loss: 4.299387 | loc loss:3.124243 | class loss:1.175144
# Epoch: 140/200  | Epoch time 28.158 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_140.h5<<<<<<<<<<
# Epoch: 141/200 | Batch 201/201 | Batch time 0.109 || Loss: 4.311934 | loc loss:3.151978 | class loss:1.159956
# Epoch: 141/200  | Epoch time 27.940 || Average Loss: inf
# Epoch: 142/200 | Batch 201/201 | Batch time 0.104 || Loss: 3.354209 | loc loss:2.190665 | class loss:1.163544
# Epoch: 142/200  | Epoch time 28.306 || Average Loss: inf
# Epoch: 143/200 | Batch 201/201 | Batch time 0.105 || Loss: 5.023067 | loc loss:3.964435 | class loss:1.058632
# Epoch: 143/200  | Epoch time 27.577 || Average Loss: inf
# Epoch: 144/200 | Batch 201/201 | Batch time 0.099 || Loss: 5.863269 | loc loss:4.794411 | class loss:1.068858
# Epoch: 144/200  | Epoch time 28.279 || Average Loss: inf
# Epoch: 145/200 | Batch 201/201 | Batch time 0.104 || Loss: 3.956167 | loc loss:3.108516 | class loss:0.847651
# Epoch: 145/200  | Epoch time 28.234 || Average Loss: inf
# Epoch: 146/200 | Batch 201/201 | Batch time 0.090 || Loss: 4.604404 | loc loss:3.443568 | class loss:1.160836
# Epoch: 146/200  | Epoch time 28.746 || Average Loss: inf
# Epoch: 147/200 | Batch 201/201 | Batch time 0.133 || Loss: 5.224262 | loc loss:4.068939 | class loss:1.155322
# Epoch: 147/200  | Epoch time 28.298 || Average Loss: inf
# Epoch: 148/200 | Batch 201/201 | Batch time 0.111 || Loss: 4.338587 | loc loss:3.411520 | class loss:0.927068
# Epoch: 148/200  | Epoch time 28.182 || Average Loss: inf
# Epoch: 149/200 | Batch 201/201 | Batch time 0.106 || Loss: 4.564936 | loc loss:3.417081 | class loss:1.147855
# Epoch: 149/200  | Epoch time 28.077 || Average Loss: inf
# Epoch: 150/200 | Batch 201/201 | Batch time 0.089 || Loss: 4.502282 | loc loss:3.552228 | class loss:0.950055
# Epoch: 150/200  | Epoch time 28.310 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_150.h5<<<<<<<<<<
# Epoch: 151/200 | Batch 201/201 | Batch time 0.102 || Loss: 5.098106 | loc loss:3.856205 | class loss:1.241901
# Epoch: 151/200  | Epoch time 27.717 || Average Loss: inf
# Epoch: 152/200 | Batch 201/201 | Batch time 0.113 || Loss: 3.710831 | loc loss:2.782260 | class loss:0.928571
# Epoch: 152/200  | Epoch time 28.123 || Average Loss: inf
# Epoch: 153/200 | Batch 201/201 | Batch time 0.093 || Loss: 3.598019 | loc loss:2.510849 | class loss:1.087170
# Epoch: 153/200  | Epoch time 27.945 || Average Loss: inf
# Epoch: 154/200 | Batch 201/201 | Batch time 0.113 || Loss: inf | loc loss:inf | class loss:1.103098 :1.012211
# Epoch: 154/200  | Epoch time 28.185 || Average Loss: inf
# Epoch: 155/200 | Batch 201/201 | Batch time 0.112 || Loss: 3.612602 | loc loss:2.615163 | class loss:0.997439
# Epoch: 155/200  | Epoch time 28.180 || Average Loss: inf
# Epoch: 156/200 | Batch 201/201 | Batch time 0.114 || Loss: 3.667902 | loc loss:2.678236 | class loss:0.989665
# Epoch: 156/200  | Epoch time 28.308 || Average Loss: inf
# Epoch: 157/200 | Batch 201/201 | Batch time 0.087 || Loss: inf | loc loss:inf | class loss:1.099687 :0.985507
# Epoch: 157/200  | Epoch time 28.584 || Average Loss: inf
# Epoch: 158/200 | Batch 201/201 | Batch time 0.114 || Loss: 4.238126 | loc loss:3.283375 | class loss:0.954751
# Epoch: 158/200  | Epoch time 28.140 || Average Loss: inf
# Epoch: 159/200 | Batch 201/201 | Batch time 0.098 || Loss: 4.628938 | loc loss:3.468598 | class loss:1.160340
# Epoch: 159/200  | Epoch time 28.501 || Average Loss: inf
# Epoch: 160/200 | Batch 201/201 | Batch time 0.087 || Loss: 5.043719 | loc loss:3.910228 | class loss:1.133492
# Epoch: 160/200  | Epoch time 27.951 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_160.h5<<<<<<<<<<
# Epoch: 161/200 | Batch 201/201 | Batch time 0.091 || Loss: 4.188005 | loc loss:3.039249 | class loss:1.148756
# Epoch: 161/200  | Epoch time 29.133 || Average Loss: inf
# Epoch: 162/200 | Batch 201/201 | Batch time 0.094 || Loss: 3.138591 | loc loss:2.029424 | class loss:1.109167
# Epoch: 162/200  | Epoch time 28.795 || Average Loss: inf
# Epoch: 163/200 | Batch 201/201 | Batch time 0.123 || Loss: 4.639131 | loc loss:3.437207 | class loss:1.201924
# Epoch: 163/200  | Epoch time 29.890 || Average Loss: inf
# Epoch: 164/200 | Batch 201/201 | Batch time 0.108 || Loss: 4.214829 | loc loss:3.097898 | class loss:1.116931
# Epoch: 164/200  | Epoch time 29.350 || Average Loss: inf
# Epoch: 165/200 | Batch 201/201 | Batch time 0.097 || Loss: 4.545789 | loc loss:3.381133 | class loss:1.164656
# Epoch: 165/200  | Epoch time 31.318 || Average Loss: inf
# Epoch: 166/200 | Batch 201/201 | Batch time 0.111 || Loss: 4.731066 | loc loss:3.390480 | class loss:1.340586
# Epoch: 166/200  | Epoch time 31.291 || Average Loss: inf
# Epoch: 167/200 | Batch 201/201 | Batch time 0.118 || Loss: 4.187006 | loc loss:2.796185 | class loss:1.390821
# Epoch: 167/200  | Epoch time 31.932 || Average Loss: inf
# Epoch: 168/200 | Batch 201/201 | Batch time 0.109 || Loss: 3.983708 | loc loss:2.908756 | class loss:1.074951
# Epoch: 168/200  | Epoch time 33.031 || Average Loss: inf
# Epoch: 169/200 | Batch 201/201 | Batch time 0.098 || Loss: inf | loc loss:inf | class loss:1.130993 :1.112916
# Epoch: 169/200  | Epoch time 33.495 || Average Loss: inf
# Epoch: 170/200 | Batch 201/201 | Batch time 0.118 || Loss: 6.683039 | loc loss:5.400621 | class loss:1.282418
# Epoch: 170/200  | Epoch time 33.480 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_170.h5<<<<<<<<<<
# Epoch: 171/200 | Batch 201/201 | Batch time 0.118 || Loss: 4.387252 | loc loss:3.224426 | class loss:1.162826
# Epoch: 171/200  | Epoch time 33.291 || Average Loss: inf
# Epoch: 172/200 | Batch 201/201 | Batch time 0.131 || Loss: 4.477629 | loc loss:3.285688 | class loss:1.191941
# Epoch: 172/200  | Epoch time 33.751 || Average Loss: inf
# Epoch: 173/200 | Batch 201/201 | Batch time 0.095 || Loss: 4.887416 | loc loss:3.897691 | class loss:0.989726
# Epoch: 173/200  | Epoch time 33.171 || Average Loss: inf
# Epoch: 174/200 | Batch 201/201 | Batch time 0.126 || Loss: 5.510727 | loc loss:4.207077 | class loss:1.303650
# Epoch: 174/200  | Epoch time 33.276 || Average Loss: inf
# Epoch: 175/200 | Batch 201/201 | Batch time 0.128 || Loss: 5.300775 | loc loss:4.062395 | class loss:1.238380
# Epoch: 175/200  | Epoch time 32.996 || Average Loss: inf
# Epoch: 176/200 | Batch 201/201 | Batch time 0.083 || Loss: 4.768749 | loc loss:3.865997 | class loss:0.902752
# Epoch: 176/200  | Epoch time 32.872 || Average Loss: inf
# Epoch: 177/200 | Batch 201/201 | Batch time 0.151 || Loss: 3.466296 | loc loss:2.274293 | class loss:1.192003
# Epoch: 177/200  | Epoch time 33.463 || Average Loss: inf
# Epoch: 178/200 | Batch 201/201 | Batch time 0.109 || Loss: 3.729673 | loc loss:2.747181 | class loss:0.982492
# Epoch: 178/200  | Epoch time 32.595 || Average Loss: inf
# Epoch: 179/200 | Batch 201/201 | Batch time 0.138 || Loss: 3.822156 | loc loss:2.716311 | class loss:1.105845
# Epoch: 179/200  | Epoch time 33.685 || Average Loss: inf
# Epoch: 180/200 | Batch 201/201 | Batch time 0.104 || Loss: 4.924888 | loc loss:3.877475 | class loss:1.047413
# Epoch: 180/200  | Epoch time 32.875 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_180.h5<<<<<<<<<<
# Epoch: 181/200 | Batch 201/201 | Batch time 0.084 || Loss: 3.649930 | loc loss:2.652951 | class loss:0.996980
# Epoch: 181/200  | Epoch time 33.571 || Average Loss: inf
# Epoch: 182/200 | Batch 201/201 | Batch time 0.131 || Loss: 3.900193 | loc loss:2.798009 | class loss:1.102184
# Epoch: 182/200  | Epoch time 33.358 || Average Loss: inf
# Epoch: 183/200 | Batch 201/201 | Batch time 0.121 || Loss: 4.352879 | loc loss:3.247507 | class loss:1.105372
# Epoch: 183/200  | Epoch time 32.816 || Average Loss: inf
# Epoch: 184/200 | Batch 201/201 | Batch time 0.094 || Loss: 4.822982 | loc loss:3.798948 | class loss:1.024034
# Epoch: 184/200  | Epoch time 33.120 || Average Loss: inf
# Epoch: 185/200 | Batch 201/201 | Batch time 0.106 || Loss: 3.677851 | loc loss:2.661696 | class loss:1.016155
# Epoch: 185/200  | Epoch time 33.580 || Average Loss: inf
# Epoch: 186/200 | Batch 201/201 | Batch time 0.092 || Loss: 4.046710 | loc loss:2.958712 | class loss:1.087998
# Epoch: 186/200  | Epoch time 33.690 || Average Loss: inf
# Epoch: 187/200 | Batch 201/201 | Batch time 0.102 || Loss: 3.155828 | loc loss:2.152588 | class loss:1.003239
# Epoch: 187/200  | Epoch time 32.565 || Average Loss: inf
# Epoch: 188/200 | Batch 201/201 | Batch time 0.088 || Loss: 4.995230 | loc loss:3.880715 | class loss:1.114515
# Epoch: 188/200  | Epoch time 33.903 || Average Loss: inf
# Epoch: 189/200 | Batch 201/201 | Batch time 0.090 || Loss: 3.786843 | loc loss:2.540178 | class loss:1.246665
# Epoch: 189/200  | Epoch time 31.909 || Average Loss: inf
# Epoch: 190/200 | Batch 201/201 | Batch time 0.118 || Loss: 4.341121 | loc loss:3.363791 | class loss:0.977331
# Epoch: 190/200  | Epoch time 33.394 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_190.h5<<<<<<<<<<
# Epoch: 191/200 | Batch 201/201 | Batch time 0.116 || Loss: 4.423436 | loc loss:3.111562 | class loss:1.311875
# Epoch: 191/200  | Epoch time 33.325 || Average Loss: inf
# Epoch: 192/200 | Batch 201/201 | Batch time 0.094 || Loss: 4.536151 | loc loss:3.510783 | class loss:1.025368
# Epoch: 192/200  | Epoch time 33.550 || Average Loss: inf
# Epoch: 193/200 | Batch 201/201 | Batch time 0.112 || Loss: 3.852462 | loc loss:2.735982 | class loss:1.116480
# Epoch: 193/200  | Epoch time 33.093 || Average Loss: inf
# Epoch: 194/200 | Batch 201/201 | Batch time 0.129 || Loss: 3.765707 | loc loss:2.739339 | class loss:1.026367
# Epoch: 194/200  | Epoch time 33.213 || Average Loss: inf
# Epoch: 195/200 | Batch 201/201 | Batch time 0.128 || Loss: 3.733420 | loc loss:2.696272 | class loss:1.037148
# Epoch: 195/200  | Epoch time 33.919 || Average Loss: inf
# Epoch: 196/200 | Batch 201/201 | Batch time 0.106 || Loss: 5.109942 | loc loss:3.900020 | class loss:1.209922
# Epoch: 196/200  | Epoch time 33.144 || Average Loss: inf
# Epoch: 197/200 | Batch 201/201 | Batch time 0.122 || Loss: 4.631775 | loc loss:3.506395 | class loss:1.125380
# Epoch: 197/200  | Epoch time 33.639 || Average Loss: inf
# Epoch: 198/200 | Batch 201/201 | Batch time 0.128 || Loss: 4.392041 | loc loss:3.330515 | class loss:1.061526
# Epoch: 198/200  | Epoch time 32.686 || Average Loss: inf
# Epoch: 199/200 | Batch 201/201 | Batch time 0.122 || Loss: 3.580428 | loc loss:2.637041 | class loss:0.943387
# Epoch: 199/200  | Epoch time 33.637 || Average Loss: inf
# Epoch: 200/200 | Batch 201/201 | Batch time 0.134 || Loss: inf | loc loss:inf | class loss:1.088143 :0.981917
# Epoch: 200/200  | Epoch time 32.938 || Average Loss: inf
# >>>>>>>>>>Save weights file at /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_200.h5<<<<<<<<<<

# %% [markdown]
# #### NMS 구현

# %%
def compute_nms(boxes, scores, nms_threshold=0.5, limit=200):
    """ Perform Non Maximum Suppression algorithm
        to eliminate boxes with high overlap
    Args:
        boxes: tensor (num_boxes, 4)
               of format (xmin, ymin, xmax, ymax)
        scores: tensor (num_boxes,)
        nms_threshold: NMS threshold
        limit: maximum number of boxes to keep
    Returns:
        idx: indices of kept boxes
    """
    if boxes.shape[0] == 0:
        return tf.constant([], dtype=tf.int32)
    selected = [0]
    idx = tf.argsort(scores, direction='DESCENDING')
    idx = idx[:limit]
    boxes = tf.gather(boxes, idx)

    iou = _jaccard(boxes, boxes)

    while True:
        row = iou[selected[-1]]
        next_indices = row <= nms_threshold

        iou = tf.where(
            tf.expand_dims(tf.math.logical_not(next_indices), 0),
            tf.ones_like(iou, dtype=tf.float32),
            iou)

        if not tf.math.reduce_any(next_indices):
            break

        selected.append(tf.argsort(
            tf.dtypes.cast(next_indices, tf.int32), direction='DESCENDING')[0].numpy())

    return tf.gather(idx, selected)

# %%
def decode_bbox_tf(pre, priors, variances=None):
    """Decode locations from predictions using prior to undo
    the encoding we did for offset regression at train time.
    Args:
        pre (tensor): location predictions for loc layers,
            Shape: [num_prior,4]
        prior (tensor): Prior boxes in center-offset form.
            Shape: [num_prior,4].
        variances: (list[float]) Variances of prior boxes
    Return:
        decoded bounding box predictions xmin, ymin, xmax, ymax
    """
    if variances is None:
        variances = [0.1, 0.2]
    centers = priors[:, :2] + pre[:, :2] * variances[0] * priors[:, 2:]
    sides = priors[:, 2:] * tf.math.exp(pre[:, 2:] * variances[1])

    return tf.concat([centers - sides / 2, centers + sides / 2], axis=1)

# %%
def parse_predict(predictions, priors, cfg):
    label_classes = cfg['labels_list']

    bbox_regressions, confs = tf.split(predictions[0], [4, -1], axis=-1)
    boxes = decode_bbox_tf(bbox_regressions, priors, cfg['variances'])


    confs = tf.math.softmax(confs, axis=-1)

    out_boxes = []
    out_labels = []
    out_scores = []

    for c in range(1, len(label_classes)):
        cls_scores = confs[:, c]

        score_idx = cls_scores > cfg['score_threshold']

        cls_boxes = boxes[score_idx]
        cls_scores = cls_scores[score_idx]

        nms_idx = compute_nms(cls_boxes, cls_scores, cfg['nms_threshold'], cfg['max_number_keep'])

        cls_boxes = tf.gather(cls_boxes, nms_idx)
        cls_scores = tf.gather(cls_scores, nms_idx)

        cls_labels = [c] * cls_boxes.shape[0]

        out_boxes.append(cls_boxes)
        out_labels.extend(cls_labels)
        out_scores.append(cls_scores)

    out_boxes = tf.concat(out_boxes, axis=0)
    out_scores = tf.concat(out_scores, axis=0)

    boxes = tf.clip_by_value(out_boxes, 0.0, 1.0).numpy()
    classes = np.array(out_labels)
    scores = out_scores.numpy()

    return boxes, classes, scores

# %%
def pad_input_image(img, max_steps):
    """pad image to suitable shape"""
    img_h, img_w, _ = img.shape

    img_pad_h = 0
    if img_h % max_steps > 0:
        img_pad_h = max_steps - img_h % max_steps

    img_pad_w = 0
    if img_w % max_steps > 0:
        img_pad_w = max_steps - img_w % max_steps

    padd_val = np.mean(img, axis=(0, 1)).astype(np.uint8)
    img = cv2.copyMakeBorder(img, 0, img_pad_h, 0, img_pad_w,
                             cv2.BORDER_CONSTANT, value=padd_val.tolist())
    pad_params = (img_h, img_w, img_pad_h, img_pad_w)

    return img, pad_params

# %%
def recover_pad_output(outputs, pad_params):
    """
        recover the padded output effect

    """
    img_h, img_w, img_pad_h, img_pad_w = pad_params

    recover_xy = np.reshape(outputs[0], [-1, 2, 2]) * \
                 [(img_pad_w + img_w) / img_w, (img_pad_h + img_h) / img_h]
    outputs[0] = np.reshape(recover_xy, [-1, 4])

    return outputs

# %%
global model

min_sizes = cfg['min_sizes']
num_cell = [len(min_sizes[k]) for k in range(len(cfg['steps']))]
model_path = os.getenv('HOME')+'/aiffel/face_detector/checkpoints'
img_path = os.getenv('HOME')+'/aiffel/face_detector/image.png'

try:
    model = SsdModel(cfg=cfg, num_cell=num_cell, training=False)

    paths = [os.path.join(model_path, path)
             for path in os.listdir(model_path)]
    latest = sorted(paths, key=os.path.getmtime)[-1]
    model.load_weights(latest)
    print(f"model path : {latest}")

except AttributeError as e:
    print('Please make sure there is at least one weights at {}'.format(model_path))

if not os.path.exists(img_path):
    print(f"Cannot find image path from {img_path}")
    exit()
print("[*] Predict {} image.. ".format(img_path))
img_raw = cv2.imread(img_path)
img_raw = cv2.resize(img_raw, (320, 240))
img_height_raw, img_width_raw, _ = img_raw.shape
img = np.float32(img_raw.copy())

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# pad input image to avoid unmatched shape problem
img, pad_params = pad_input_image(img, max_steps=max(cfg['steps']))
img = img / 255.0 - 0.5
print(img.shape)
priors, _ = prior_box(cfg, image_sizes=(img.shape[0], img.shape[1]))
priors = tf.cast(priors, tf.float32)

predictions = model.predict(img[np.newaxis, ...])

boxes, classes, scores = parse_predict(predictions, priors, cfg)

print(f"scores:{scores}")
# Out:
# model path : /home/ubuntu/aiffel/face_detector/checkpoints/weights_epoch_200.h5
# [*] Predict /home/ubuntu/aiffel/face_detector/image.png image..
# (256, 320, 3)
# scores:[0.98704267 0.9565663  0.92994314 0.7242365  0.686145  ]

# %%
boxes = recover_pad_output(boxes, pad_params)
print(boxes)
img_bgr = img_raw.copy()

for prior_index in range(len(boxes)):
    x1, y1, x2, y2 = int(boxes[prior_index][0] * img_width_raw), int(boxes[prior_index][1] * img_height_raw), \
                     int(boxes[prior_index][2] * img_width_raw), int(boxes[prior_index][3] * img_height_raw)
    if classes[prior_index] == 1:
        color = (0, 255, 0)
    else:
        color = (0, 0, 255)
    cv2.rectangle(img_bgr, (x1, y1), (x2, y2), color, 2)

img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
# Out:
# [[0.738914   0.20799583 0.92166615 0.45372444]
#  [0.5911482  0.09396213 0.73841125 0.27441275]
#  [0.31669062 0.16300075 0.49192733 0.3688473 ]
#  [0.01496367 0.15906161 0.17399205 0.36943823]
#  [0.451702   0.47461164 0.6211053  0.6757065 ]]

# %% [markdown]
# ### Step 3. dlib을 이용한 landmark 찾기

# %%
import dlib

img_bgr = img_raw.copy()
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

detector_hog = dlib.get_frontal_face_detector()
dlib_rects = detector_hog(img_rgb, 1)

landmark_predictor = dlib.shape_predictor('./shape_predictor_68_face_landmarks.dat')

list_landmarks = []
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

list_landmarks
for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_bgr, point, 1, (0, 255, 255), -1)
        
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### Step 4. 스티커 합성 사진 생성하기

# %%
img_bgr = img_raw.copy()
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):

    x = landmark[30][0] # nose
    y = landmark[30][1] - dlib_rect.width()//2
    w = dlib_rect.width()
    h = dlib_rect.width()

    img_sticker = cv2.resize(img_sticker, (w, h), interpolation=cv2.INTER_NEAREST)

    refined_x = x - w // 2
    refined_y = y - h

    if refined_y < 0:
        img_sticker = img_sticker[-refined_y:]
        refined_y = 0

    sticker_area = img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]

    img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
        cv2.addWeighted(sticker_area, 1.0, img_sticker, 0.7, 0)

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
