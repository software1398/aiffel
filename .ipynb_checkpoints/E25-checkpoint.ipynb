# %% [markdown]
# ## E25 - Spectrogram classification 모델 구현
# ### 1. 데이터 처리와 분류

# %%
import numpy as np
import os

data_path = os.getenv("HOME")+'/aiffel/speech_recognition/data/speech_wav_8000.npz'
speech_data = np.load(data_path)

# %%
speech_data.files
# Out:
# ['wav_vals', 'label_vals']

# %%
print("Wave data shape:", speech_data["wav_vals"].shape)
print("Label data shape:", speech_data["label_vals"].shape)
# Out:
# Wave data shape: (50620, 8000)
# Label data shape: (50620, 1)

# %%
import librosa

def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D

# %%
import random
rand = random.randint(0, len(speech_data["wav_vals"]))
data = speech_data["wav_vals"][rand]

# %%
spec = wav2spec(data)
print("Waveform shape : ",data.shape)
print("Spectrogram shape : ",spec.shape)
# Out:
# Waveform shape :  (8000,)
# Spectrogram shape :  (130, 126)

# %%
import librosa.display
import matplotlib.pyplot as plt

librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.xticks(range(0, 1))
plt.tight_layout()
plt.show()

# %%
spec_data = list(map(wav2spec, speech_data['wav_vals']))
spec_data = np.array(spec_data)
spec_data.shape
# Out:
# (50620, 130, 126)

# %% [markdown]
# #### 라벨 데이터 처리하기

# %%
target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']

label_value = target_list
label_value.append('unknown')
label_value.append('silence')

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value

# %%
temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)

# %% [markdown]
# #### train, test 분리

# %%
from sklearn.model_selection import train_test_split

train_spec, test_spec, train_label, test_label = train_test_split(spec_data,
                                                                  label_data, 
                                                                  test_size=0.1,
                                                                  shuffle=True)

# %%
print("train data : ", train_spec.shape)
print("train labels : ", train_label.shape)
print("test data : ", test_spec.shape)
print("test labels : ", test_label.shape)
# Out:
# train data :  (45558, 130, 126)
# train labels :  (45558,)
# test data :  (5062, 130, 126)
# test labels :  (5062,)

# %%
train_spec[0]
# Out:
# array([[5.0651884e-01, 3.5982171e-01, 7.8741588e-02, ..., 1.3571472e+00,
#         3.4878831e+00, 6.0479951e+00],
#        [3.7593248e-01, 1.9237079e-01, 1.8910761e-01, ..., 2.4551494e+00,
#         3.4596055e+00, 3.8788834e+00],
#        [1.4772391e-01, 1.5430358e-01, 2.1428196e-01, ..., 8.3228624e-01,
#         1.3828561e+00, 6.0884279e-01],
#        ...,
#        [8.8868449e-03, 4.6521570e-03, 4.3208583e-04, ..., 2.9407709e-04,
#         1.2842995e-03, 2.9583103e-03],
#        [8.9239916e-03, 4.5096660e-03, 2.3315029e-04, ..., 3.1031221e-05,
#         1.9232125e-03, 3.4939277e-03],
#        [8.8458909e-03, 4.4297390e-03, 1.6100534e-04, ..., 1.3601343e-04,
#         2.0875712e-03, 3.8076821e-03]], dtype=float32)

# %% [markdown]
# ### 2. 학습을 위한 하이퍼파라미터 설정

# %%
batch_size = 128
max_epochs = 10

# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/spec'

checkpoint_dir
# Out:
# '/home/aiffel0042/aiffel/speech_recognition/models/spec'

# %% [markdown]
# ### 3. 데이터셋 구성

# %%
def one_hot_label(wav, label):
    label = tf.one_hot(label, depth=12)
    return wav, label

# %%
import tensorflow as tf

# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_spec, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_spec, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)
# Out:
# <BatchDataset shapes: ((None, 130, 126), (None, 12)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 130, 126), (None, 12)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ### 4. 2차원 Spectrogram을 처리하는 모델 구성

# %%
from tensorflow.keras import layers

input_tensor = layers.Input(shape=(130, 126, 1))

x = layers.Conv2D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv2D(32, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(64, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(64, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_spec = tf.keras.Model(input_tensor, output_tensor)

model_spec.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 130, 126, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 130, 126, 32)      2624
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 130, 126, 32)      82976
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 65, 63, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 65, 63, 64)        165952
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 65, 63, 64)        331840
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 31, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 31, 128)       663680
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 31, 128)       1327232
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 31, 128)       1327232
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 15, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 15, 256)       2654464
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 15, 256)       5308672
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 15, 256)       5308672
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 7, 256)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 7, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 14336)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               3670272
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 20,847,724
# Trainable params: 20,847,212
# Non-trainable params: 512
# _________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
model_spec.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                   optimizer=optimizer,
                   metrics=['accuracy'])

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)

# %%
history_spec = model_spec.fit(train_dataset, epochs=max_epochs,                              
                            steps_per_epoch=len(train_spec) // batch_size,
                            validation_data=test_dataset,
                            validation_steps=len(test_spec) // batch_size,
                            callbacks=[cp_callback]
                            )
# Out:
# Epoch 1/10
# 355/355 [==============================] - ETA: 0s - loss: 0.8292 - accuracy: 0.7231
# Epoch 00001: val_loss improved from inf to 0.47325, saving model to /home/aiffel0042/aiffel/speech_recognition/models/spec
# 355/355 [==============================] - 167s 471ms/step - loss: 0.8292 - accuracy: 0.7231 - val_loss: 0.4733 - val_accuracy: 0.8848
# Epoch 2/10
# 355/355 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.9167
# Epoch 00002: val_loss improved from 0.47325 to 0.21781, saving model to /home/aiffel0042/aiffel/speech_recognition/models/spec
# 355/355 [==============================] - 171s 482ms/step - loss: 0.2577 - accuracy: 0.9167 - val_loss: 0.2178 - val_accuracy: 0.9293
# Epoch 3/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9447
# Epoch 00003: val_loss improved from 0.21781 to 0.17718, saving model to /home/aiffel0042/aiffel/speech_recognition/models/spec
# 355/355 [==============================] - 168s 473ms/step - loss: 0.1720 - accuracy: 0.9447 - val_loss: 0.1772 - val_accuracy: 0.9415
# Epoch 4/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9581
# Epoch 00004: val_loss did not improve from 0.17718
# 355/355 [==============================] - 166s 468ms/step - loss: 0.1288 - accuracy: 0.9581 - val_loss: 0.2280 - val_accuracy: 0.9259
# Epoch 5/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9657
# Epoch 00005: val_loss did not improve from 0.17718
# 355/355 [==============================] - 166s 469ms/step - loss: 0.1031 - accuracy: 0.9657 - val_loss: 0.1953 - val_accuracy: 0.9433
# Epoch 6/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9710
# Epoch 00006: val_loss improved from 0.17718 to 0.14344, saving model to /home/aiffel0042/aiffel/speech_recognition/models/spec
# 355/355 [==============================] - 167s 471ms/step - loss: 0.0873 - accuracy: 0.9710 - val_loss: 0.1434 - val_accuracy: 0.9541
# Epoch 7/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9744
# Epoch 00007: val_loss improved from 0.14344 to 0.13459, saving model to /home/aiffel0042/aiffel/speech_recognition/models/spec
# 355/355 [==============================] - 167s 470ms/step - loss: 0.0754 - accuracy: 0.9744 - val_loss: 0.1346 - val_accuracy: 0.9573
# Epoch 8/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9787
# Epoch 00008: val_loss improved from 0.13459 to 0.12699, saving model to /home/aiffel0042/aiffel/speech_recognition/models/spec
# 355/355 [==============================] - 167s 470ms/step - loss: 0.0640 - accuracy: 0.9787 - val_loss: 0.1270 - val_accuracy: 0.9623
# Epoch 9/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9790
# Epoch 00009: val_loss improved from 0.12699 to 0.10573, saving model to /home/aiffel0042/aiffel/speech_recognition/models/spec
# 355/355 [==============================] - 175s 492ms/step - loss: 0.0629 - accuracy: 0.9790 - val_loss: 0.1057 - val_accuracy: 0.9657
# Epoch 10/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9800
# Epoch 00010: val_loss did not improve from 0.10573
# 355/355 [==============================] - 169s 476ms/step - loss: 0.0576 - accuracy: 0.9800 - val_loss: 0.1088 - val_accuracy: 0.9661

# %%
acc = history_spec.history['accuracy']
val_acc = history_spec.history['val_accuracy']

loss=history_spec.history['loss']
val_loss=history_spec.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### 모델 성능 평가

# %%
model_spec.load_weights(checkpoint_dir)
results = model_spec.evaluate(test_dataset)

# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
# Out:
# 40/40 [==============================] - 27s 668ms/step - loss: 0.1059 - accuracy: 0.9654
# loss value: 0.106
# accuracy value: 96.5429%

# %%
inv_label_value = {v: k for k, v in label_value.items()}
batch_index = np.random.choice(len(test_spec), size=1, replace=False)

batch_xs = test_spec[batch_index]
batch_ys = test_label[batch_index]
y_pred_ = model_spec(batch_xs, training=False)

print("label : ", str(inv_label_value[batch_ys[0]]))
# Out:
# label :  off

# %%
if np.argmax(y_pred_) == test_label[i]:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]))
else:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]))
# Out:
# y_pred: off
